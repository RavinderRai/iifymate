# %% [markdown]
# # Data Collection
#
# We are using the EDAMAM API to collect data. Here we explore its functionality and what kind of data, and types of format, we can get using the free tier.
#
# Visit this link for API keys: https://developer.edamam.com/admin/applications.

# %%
import os
import requests
import pandas as pd

edamam_api_id = os.environ["EDAMAM_API_ID"]
edamam_api_key = os.environ["EDAMAM_API_KEY"]

# %% [markdown]
# ## Initial Exploration

# %%
def recipe_search(ingredient, from_index=0, to_index=10):
    if to_index > 100:
        raise ValueError("to_index must be 100 at maximum")
    
    app_id = edamam_api_id  # Replace with your Edamam API app ID
    app_key = edamam_api_key  # Replace with your Edamam API app key
    result = requests.get(
        'https://api.edamam.com/search?q={}&app_id={}&app_key={}&from={}&to={}'.format(
            ingredient, app_id, app_key, from_index, to_index
        )
    )
    data = result.json()
    return data['hits']

def get_recipe_df(recipes):
    recipes_lst = [recipes[i]['recipe'] for i in range(len(recipes))]
    return pd.DataFrame(recipes_lst)

# %%
recipes = recipe_search("broccoli")

# %%
recipes[0]['recipe']
# Out:
# {'uri': 'http://www.edamam.com/ontologies/edamam.owl#recipe_543023fc1fef4a1448c2acd81155f12c',
#  'label': 'Steamed Broccoli',
#  'image': 'https://edamam-product-images.s3.amazonaws.com/web-img/5d4/5d4b2cfd62d545fbd0d9bc9b89f96530?X-Amz-Security-Token=IQoJb3JpZ2luX2VjED0aCXVzLWVhc3QtMSJGMEQCIAWX3KTA1ApTQ780MrFvNBm9Wv2rYlmT5IBi5zNMjabhAiA8HfPx6v66rA7u440QinAUbNpXWtw3ak%2BnriRMqTgyyyq5BQhGEAAaDDE4NzAxNzE1MDk4NiIMr3N%2F%2F8J5NCew8u0DKpYF%2BUDUk53O1Py6kdq%2FA0neYoP6tVxA%2FSxXb2h73Sld8SAppr6B40qcMabAY1gihHpEtcbqtUf9mTEIGtRRcdvYigNynsIrtNgMM8TzrFtlaxu4YqtzPEecBh%2F9iiGWAyjfs0eOomlte9FUNyRJKbSAUpgnKKTWgaKBQJqUcJFpcyWJ2UaWOpgMhcGiaEnPKdto9n1TL6prHUQHDugcA75xS9DHkgEbNfJzpdGry6QHqSR4h9Vdt8Kvd%2B76%2FN8bwSjRPLGSXx9kcs%2BZPRt%2BpWLUHaRQL9nFAHXZSKXfhkpYOl9ZZI%2F4%2FJSnuVk2PsJCE6i0iK1BMQtivHM92uK1ejmFYts87W5yPVt%2FtvFtLYlJKCB4u0iBBcrDj%2F60N80K1doS7ODcweKGJ73s4BKpbZQJJiixUGIiJ6g07VZrHQHGjqNCzmGrPm1IR73hPGL%2FPqjXP0dsd1BXt0JlHTQIj9xtizfRPSNLHWRHTo2vq3h4jB5rGOuQ5AU1YmlvZf9UsXbS2HQThC42hs1g1W0xN0qKpxJj4ArbigrdO11RBozkz5vaVa8CjVTcZPcLx26SB32rZbhJ6bbiLKuvh0t%2FBjrbi2E9QhchWnzbCVe0yXDM5LW%2BeUDjjnZBqOp95js0CzJ1OAlt9Yazi9gVm5Y2hcypA711Qvl1lPEJvrOe1NmSDyjyurblKbnrSENj%2FcNlHgFouS0VeUfYrw4Izzv5q1a9RLgWiu1rU%2BL%2BgicTcDatDNNLs9%2BMxJ%2FmmeSZqgHdPfAuacY13B4K5lcMljU3soZmROrIYtBXE677EXjgrX4LG6%2Bqx8alUIhJFxQW4ZfjuwGjUytGSliS0uVsrG5aLBFREeHWX%2FVaysM6IYS%2B%2B9WGi70efIFh%2BDww1t7YvAY6sgFvBLPmlBVcd272%2BxWY%2F%2F08FyL%2BwTW5k1pxYwLbPs5IjRgGPEtY7XJJHsMkgWuKB50vjwAfW4smQ2oQC62m2ysOaYPZQe888nV6NDjyu40WONoK0MO2F4geAflRyKUugty4WJrxEcjblx%2F5I1H18dHRWdl7fgrrtr2yQm4bcu9BTGw1fNN83Q39x6NrA4NVuK%2Flm8LdGuUDFV%2BRd%2BFl2CtKtxMrIyCNmGM%2FyDrC3OFe7YGQ&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Date=20250126T140119Z&X-Amz-SignedHeaders=host&X-Amz-Expires=3599&X-Amz-Credential=ASIASXCYXIIFN4RH5WMC%2F20250126%2Fus-east-1%2Fs3%2Faws4_request&X-Amz-Signature=f9a8ea818703e99c12b4dc2100ce02c0089ecdc75fe5b4d056fe1f99f48265fb',
#  'source': 'Martha Stewart',
#  'url': 'https://www.marthastewart.com/924840/steamed-broccoli',
#  'shareAs': 'http://www.edamam.com/recipe/steamed-broccoli-543023fc1fef4a1448c2acd81155f12c/broccoli',
#  'yield': 2.0,
#  'dietLabels': ['High-Fiber', 'Low-Fat'],
#  'healthLabels': ['Vegan',
#   'Vegetarian',
#   'Pescatarian',
#   'DASH',
#   'Dairy-Free',
#   'Gluten-Free',
#   'Wheat-Free',
#   'Egg-Free',
#   'Peanut-Free',
#   'Tree-Nut-Free',
#   'Soy-Free',
#   'Fish-Free',
#   'Shellfish-Free',
#   'Pork-Free',
#   'Red-Meat-Free',
#   'Crustacean-Free',
#   'Celery-Free',
#   'Sesame-Free',
#   'Lupine-Free',
#   'Mollusk-Free',
#   'Alcohol-Free',
#   'Sulfite-Free',
#   'FODMAP-Free',
#   'Kosher',
#   'Immuno-Supportive'],
#  'cautions': [],
#  'ingredientLines': ['1 bunch broccoli',
#   'Dijon Vinaigrette, for serving (optional)'],
#  'ingredients': [{'text': '1 bunch broccoli',
#    'quantity': 1.0,
#    'measure': 'bunch',
#    'food': 'broccoli',
#    'weight': 608.0,
#    'foodCategory': 'vegetables',
#    'foodId': 'food_aahw0jha9f8337ajbopx9aec6z7i',
#    'image': 'https://www.edamam.com/food-img/3e4/3e47317a3dd54dc911b9c44122285df1.jpg'},
#   {'text': 'Dijon Vinaigrette, for serving (optional)',
#    'quantity': 1.0,
#    'measure': 'serving',
#    'food': 'Dijon',
#    'weight': 30.0,
#    'foodCategory': 'Condiments and sauces',
#    'foodId': 'food_a34cdj5b0kyuhfbov30xcb50u4dv',
#    'image': 'https://www.edamam.com/food-img/e23/e238f2e4cfa6aa1a30f46dc73e7344eb.jpg'}],
#  'calories': 224.72,
#  'totalWeight': 638.0,
#  'totalTime': 0.0,
#  'cuisineType': ['nordic'],
#  'mealType': ['lunch/dinner'],
#  'dishType': ['starter'],
#  'totalNutrients': {'ENERC_KCAL': {'label': 'Energy',
#    'quantity': 224.72,
#    'unit': 'kcal'},
#   'FAT': {'label': 'Fat', 'quantity': 3.2516, 'unit': 'g'},
#   'FASAT': {'label': 'Saturated', 'quantity': 0.7573200000000001, 'unit': 'g'},
#   'FATRN': {'label': 'Trans', 'quantity': 0.0026999999999999997, 'unit': 'g'},
#   'FAMS': {'label': 'Monounsaturated', 'quantity': 0.84248, 'unit': 'g'},
#   'FAPU': {'label': 'Polyunsaturated', 'quantity': 0.91316, 'unit': 'g'},
#   'CHOCDF': {'label': 'Carbs', 'quantity': 42.120200000000004, 'unit': 'g'},
#   'CHOCDF.net': {'label': 'Carbohydrates (net)',
#    'quantity': 25.1122,
#    'unit': 'g'},
#   'FIBTG': {'label': 'Fiber', 'quantity': 17.008000000000003, 'unit': 'g'},
#   'SUGAR': {'label': 'Sugars', 'quantity': 10.612, 'unit': 'g'},
#   'PROCNT': {'label': 'Protein', 'quantity': 18.267599999999998, 'unit': 'g'},
#   'CHOLE': {'label': 'Cholesterol', 'quantity': 0.0, 'unit': 'mg'},
#   'NA': {'label': 'Sodium', 'quantity': 530.64, 'unit': 'mg'},
#   'CA': {'label': 'Calcium', 'quantity': 304.65999999999997, 'unit': 'mg'},
#   'MG': {'label': 'Magnesium', 'quantity': 142.08, 'unit': 'mg'},
#   'K': {'label': 'Potassium', 'quantity': 1966.8799999999999, 'unit': 'mg'},
#   'FE': {'label': 'Iron', 'quantity': 4.921399999999999, 'unit': 'mg'},
#   'ZN': {'label': 'Zinc', 'quantity': 2.6848, 'unit': 'mg'},
#   'P': {'label': 'Phosphorus', 'quantity': 433.68, 'unit': 'mg'},
#   'VITA_RAE': {'label': 'Vitamin A', 'quantity': 189.98, 'unit': 'µg'},
#   'VITC': {'label': 'Vitamin C', 'quantity': 542.426, 'unit': 'mg'},
#   'THIA': {'label': 'Thiamin (B1)',
#    'quantity': 0.48477999999999993,
#    'unit': 'mg'},
#   'RIBF': {'label': 'Riboflavin (B2)',
#    'quantity': 0.7323600000000001,
#    'unit': 'mg'},
#   'NIA': {'label': 'Niacin (B3)', 'quantity': 4.05462, 'unit': 'mg'},
#   'VITB6A': {'label': 'Vitamin B6',
#    'quantity': 1.0849999999999997,
#    'unit': 'mg'},
#   'FOLDFE': {'label': 'Folate equivalent (total)',
#    'quantity': 385.14000000000004,
#    'unit': 'µg'},
#   'FOLFD': {'label': 'Folate (food)',
#    'quantity': 385.14000000000004,
#    'unit': 'µg'},
#   'FOLAC': {'label': 'Folic acid', 'quantity': 0.0, 'unit': 'µg'},
#   'VITB12': {'label': 'Vitamin B12', 'quantity': 0.0, 'unit': 'µg'},
#   'VITD': {'label': 'Vitamin D', 'quantity': 0.0, 'unit': 'µg'},
#   'TOCPHA': {'label': 'Vitamin E', 'quantity': 4.8504, 'unit': 'mg'},
#   'VITK1': {'label': 'Vitamin K', 'quantity': 620.5799999999999, 'unit': 'µg'},
#   'WATER': {'label': 'Water', 'quantity': 568.054, 'unit': 'g'}},
#  'totalDaily': {'ENERC_KCAL': {'label': 'Energy',
#    'quantity': 11.236,
#    'unit': '%'},
#   'FAT': {'label': 'Fat', 'quantity': 5.002461538461538, 'unit': '%'},
#   'FASAT': {'label': 'Saturated', 'quantity': 3.786600000000001, 'unit': '%'},
#   'CHOCDF': {'label': 'Carbs', 'quantity': 14.040066666666668, 'unit': '%'},
#   'FIBTG': {'label': 'Fiber', 'quantity': 68.03200000000001, 'unit': '%'},
#   'PROCNT': {'label': 'Protein', 'quantity': 36.535199999999996, 'unit': '%'},
#   'CHOLE': {'label': 'Cholesterol', 'quantity': 0.0, 'unit': '%'},
#   'NA': {'label': 'Sodium', 'quantity': 22.11, 'unit': '%'},
#   'CA': {'label': 'Calcium', 'quantity': 30.465999999999998, 'unit': '%'},
#   'MG': {'label': 'Magnesium', 'quantity': 33.828571428571436, 'unit': '%'},
#   'K': {'label': 'Potassium', 'quantity': 41.848510638297874, 'unit': '%'},
#   'FE': {'label': 'Iron', 'quantity': 27.341111111111108, 'unit': '%'},
#   'ZN': {'label': 'Zinc', 'quantity': 24.40727272727273, 'unit': '%'},
#   'P': {'label': 'Phosphorus', 'quantity': 61.95428571428572, 'unit': '%'},
#   'VITA_RAE': {'label': 'Vitamin A',
#    'quantity': 21.108888888888888,
#    'unit': '%'},
#   'VITC': {'label': 'Vitamin C', 'quantity': 602.6955555555556, 'unit': '%'},
#   'THIA': {'label': 'Thiamin (B1)',
#    'quantity': 40.39833333333333,
#    'unit': '%'},
#   'RIBF': {'label': 'Riboflavin (B2)',
#    'quantity': 56.335384615384626,
#    'unit': '%'},
#   'NIA': {'label': 'Niacin (B3)', 'quantity': 25.341375, 'unit': '%'},
#   'VITB6A': {'label': 'Vitamin B6',
#    'quantity': 83.46153846153844,
#    'unit': '%'},
#   'FOLDFE': {'label': 'Folate equivalent (total)',
#    'quantity': 96.28500000000003,
#    'unit': '%'},
#   'VITB12': {'label': 'Vitamin B12', 'quantity': 0.0, 'unit': '%'},
#   'VITD': {'label': 'Vitamin D', 'quantity': 0.0, 'unit': '%'},
#   'TOCPHA': {'label': 'Vitamin E', 'quantity': 32.336, 'unit': '%'},
#   'VITK1': {'label': 'Vitamin K', 'quantity': 517.15, 'unit': '%'}},
#  'digest': [{'label': 'Fat',
#    'tag': 'FAT',
#    'schemaOrgTag': 'fatContent',
#    'total': 3.2516,
#    'hasRDI': True,
#    'daily': 5.002461538461538,
#    'unit': 'g',
#    'sub': [{'label': 'Saturated',
#      'tag': 'FASAT',
#      'schemaOrgTag': 'saturatedFatContent',
#      'total': 0.7573200000000001,
#      'hasRDI': True,
#      'daily': 3.786600000000001,
#      'unit': 'g'},
#     {'label': 'Trans',
#      'tag': 'FATRN',
#      'schemaOrgTag': 'transFatContent',
#      'total': 0.0026999999999999997,
#      'hasRDI': False,
#      'daily': 0.0,
#      'unit': 'g'},
#     {'label': 'Monounsaturated',
#      'tag': 'FAMS',
#      'schemaOrgTag': None,
#      'total': 0.84248,
#      'hasRDI': False,
#      'daily': 0.0,
#      'unit': 'g'},
#     {'label': 'Polyunsaturated',
#      'tag': 'FAPU',
#      'schemaOrgTag': None,
#      'total': 0.91316,
#      'hasRDI': False,
#      'daily': 0.0,
#      'unit': 'g'}]},
#   {'label': 'Carbs',
#    'tag': 'CHOCDF',
#    'schemaOrgTag': 'carbohydrateContent',
#    'total': 42.120200000000004,
#    'hasRDI': True,
#    'daily': 14.040066666666668,
#    'unit': 'g',
#    'sub': [{'label': 'Carbs (net)',
#      'tag': 'CHOCDF.net',
#      'schemaOrgTag': None,
#      'total': 25.1122,
#      'hasRDI': False,
#      'daily': 0.0,
#      'unit': 'g'},
#     {'label': 'Fiber',
#      'tag': 'FIBTG',
#      'schemaOrgTag': 'fiberContent',
#      'total': 17.008000000000003,
#      'hasRDI': True,
#      'daily': 68.03200000000001,
#      'unit': 'g'},
#     {'label': 'Sugars',
#      'tag': 'SUGAR',
#      'schemaOrgTag': 'sugarContent',
#      'total': 10.612,
#      'hasRDI': False,
#      'daily': 0.0,
#      'unit': 'g'},
#     {'label': 'Sugars, added',
#      'tag': 'SUGAR.added',
#      'schemaOrgTag': None,
#      'total': 0.0,
#      'hasRDI': False,
#      'daily': 0.0,
#      'unit': 'g'}]},
#   {'label': 'Protein',
#    'tag': 'PROCNT',
#    'schemaOrgTag': 'proteinContent',
#    'total': 18.267599999999998,
#    'hasRDI': True,
#    'daily': 36.535199999999996,
#    'unit': 'g'},
#   {'label': 'Cholesterol',
#    'tag': 'CHOLE',
#    'schemaOrgTag': 'cholesterolContent',
#    'total': 0.0,
#    'hasRDI': True,
#    'daily': 0.0,
#    'unit': 'mg'},
#   {'label': 'Sodium',
#    'tag': 'NA',
#    'schemaOrgTag': 'sodiumContent',
#    'total': 530.64,
#    'hasRDI': True,
#    'daily': 22.11,
#    'unit': 'mg'},
#   {'label': 'Calcium',
#    'tag': 'CA',
#    'schemaOrgTag': None,
#    'total': 304.65999999999997,
#    'hasRDI': True,
#    'daily': 30.465999999999998,
#    'unit': 'mg'},
#   {'label': 'Magnesium',
#    'tag': 'MG',
#    'schemaOrgTag': None,
#    'total': 142.08,
#    'hasRDI': True,
#    'daily': 33.828571428571436,
#    'unit': 'mg'},
#   {'label': 'Potassium',
#    'tag': 'K',
#    'schemaOrgTag': None,
#    'total': 1966.8799999999999,
#    'hasRDI': True,
#    'daily': 41.848510638297874,
#    'unit': 'mg'},
#   {'label': 'Iron',
#    'tag': 'FE',
#    'schemaOrgTag': None,
#    'total': 4.921399999999999,
#    'hasRDI': True,
#    'daily': 27.341111111111108,
#    'unit': 'mg'},
#   {'label': 'Zinc',
#    'tag': 'ZN',
#    'schemaOrgTag': None,
#    'total': 2.6848,
#    'hasRDI': True,
#    'daily': 24.40727272727273,
#    'unit': 'mg'},
#   {'label': 'Phosphorus',
#    'tag': 'P',
#    'schemaOrgTag': None,
#    'total': 433.68,
#    'hasRDI': True,
#    'daily': 61.95428571428572,
#    'unit': 'mg'},
#   {'label': 'Vitamin A',
#    'tag': 'VITA_RAE',
#    'schemaOrgTag': None,
#    'total': 189.98,
#    'hasRDI': True,
#    'daily': 21.108888888888888,
#    'unit': 'µg'},
#   {'label': 'Vitamin C',
#    'tag': 'VITC',
#    'schemaOrgTag': None,
#    'total': 542.426,
#    'hasRDI': True,
#    'daily': 602.6955555555556,
#    'unit': 'mg'},
#   {'label': 'Thiamin (B1)',
#    'tag': 'THIA',
#    'schemaOrgTag': None,
#    'total': 0.48477999999999993,
#    'hasRDI': True,
#    'daily': 40.39833333333333,
#    'unit': 'mg'},
#   {'label': 'Riboflavin (B2)',
#    'tag': 'RIBF',
#    'schemaOrgTag': None,
#    'total': 0.7323600000000001,
#    'hasRDI': True,
#    'daily': 56.335384615384626,
#    'unit': 'mg'},
#   {'label': 'Niacin (B3)',
#    'tag': 'NIA',
#    'schemaOrgTag': None,
#    'total': 4.05462,
#    'hasRDI': True,
#    'daily': 25.341375,
#    'unit': 'mg'},
#   {'label': 'Vitamin B6',
#    'tag': 'VITB6A',
#    'schemaOrgTag': None,
#    'total': 1.0849999999999997,
#    'hasRDI': True,
#    'daily': 83.46153846153844,
#    'unit': 'mg'},
#   {'label': 'Folate equivalent (total)',
#    'tag': 'FOLDFE',
#    'schemaOrgTag': None,
#    'total': 385.14000000000004,
#    'hasRDI': True,
#    'daily': 96.28500000000003,
#    'unit': 'µg'},
#   {'label': 'Folate (food)',
#    'tag': 'FOLFD',
#    'schemaOrgTag': None,
#    'total': 385.14000000000004,
#    'hasRDI': False,
#    'daily': 0.0,
#    'unit': 'µg'},
#   {'label': 'Folic acid',
#    'tag': 'FOLAC',
#    'schemaOrgTag': None,
#    'total': 0.0,
#    'hasRDI': False,
#    'daily': 0.0,
#    'unit': 'µg'},
#   {'label': 'Vitamin B12',
#    'tag': 'VITB12',
#    'schemaOrgTag': None,
#    'total': 0.0,
#    'hasRDI': True,
#    'daily': 0.0,
#    'unit': 'µg'},
#   {'label': 'Vitamin D',
#    'tag': 'VITD',
#    'schemaOrgTag': None,
#    'total': 0.0,
#    'hasRDI': True,
#    'daily': 0.0,
#    'unit': 'µg'},
#   {'label': 'Vitamin E',
#    'tag': 'TOCPHA',
#    'schemaOrgTag': None,
#    'total': 4.8504,
#    'hasRDI': True,
#    'daily': 32.336,
#    'unit': 'mg'},
#   {'label': 'Vitamin K',
#    'tag': 'VITK1',
#    'schemaOrgTag': None,
#    'total': 620.5799999999999,
#    'hasRDI': True,
#    'daily': 517.15,
#    'unit': 'µg'},
#   {'label': 'Sugar alcohols',
#    'tag': 'Sugar.alcohol',
#    'schemaOrgTag': None,
#    'total': 0.0,
#    'hasRDI': False,
#    'daily': 0.0,
#    'unit': 'g'},
#   {'label': 'Water',
#    'tag': 'WATER',
#    'schemaOrgTag': None,
#    'total': 568.054,
#    'hasRDI': False,
#    'daily': 0.0,
#    'unit': 'g'}]}

# %%
def get_recipes(from_index=0, to_index=10):
    app_id = edamam_api_id
    app_key = edamam_api_key
    
    params = {
        'type': 'public',
        'app_id': app_id,
        'app_key': app_key,
        'q': '*',  # Search all recipes
        'imageSize': 'THUMBNAIL',
        'random': 'true',
        'field': ['ingredientLines', 'calories']
    }
    
    response = requests.get('https://api.edamam.com/api/recipes/v2', params=params)
    data = response.json()
    return data['hits'] if 'hits' in data else []

# %%
get_recipes()[0]
# Out:
# {'recipe': {'ingredientLines': ['1/2 medium sized pineapple, cut into triangles',
#    '4 ounces goat cheese',
#    '1 small lime, juiced',
#    '1/4 cup freshly chopped cilantro'],
#   'calories': 541.6159642000001},
#  '_links': {'self': {'href': 'https://api.edamam.com/api/recipes/v2/64b1b6b9db872dbb3c8b9b7396b0734f?app_id=213b4d83&app_key=eb0bcd72cc7e2adc795cca5d7b6b4b37',
#    'title': 'Self'}}}

# %% [markdown]
# We can also search for food by name but there doesn't seem to be a clear indicator of serving size when looking at the nutrient data.

# %%
from dotenv import load_dotenv

load_dotenv()

edamam_food_api_id = os.environ["EDAMAM_FOOD_API_ID"]
edamam_food_api_key = os.environ["EDAMAM_FOOD_API_KEY"]

# %%
def search_food(query):
    app_id = edamam_food_api_id
    app_key = edamam_food_api_key
   
    params = {
        "app_id": app_id,
        "app_key": app_key,
        "ingr": query
    }

    response = requests.get(
        "https://api.edamam.com/api/food-database/v2/parser",
        params=params
    )

    return response.json()

# %%
search_food("broccoli")
# Out:
# {'text': 'broccoli',
#  'count': 3753,
#  'parsed': [{'food': {'foodId': 'food_aahw0jha9f8337ajbopx9aec6z7i',
#     'label': 'Broccoli',
#     'knownAs': 'broccoli',
#     'nutrients': {'ENERC_KCAL': 34.0,
#      'PROCNT': 2.82,
#      'FAT': 0.37,
#      'CHOCDF': 6.64,
#      'FIBTG': 2.6},
#     'category': 'Generic foods',
#     'categoryLabel': 'food',
#     'image': 'https://www.edamam.com/food-img/3e4/3e47317a3dd54dc911b9c44122285df1.jpg'}}],
#  'hints': [{'food': {'foodId': 'food_aahw0jha9f8337ajbopx9aec6z7i',
#     'label': 'Broccoli',
#     'knownAs': 'broccoli',
#     'nutrients': {'ENERC_KCAL': 34.0,
#      'PROCNT': 2.82,
#      'FAT': 0.37,
#      'CHOCDF': 6.64,
#      'FIBTG': 2.6},
#     'category': 'Generic foods',
#     'categoryLabel': 'food',
#     'image': 'https://www.edamam.com/food-img/3e4/3e47317a3dd54dc911b9c44122285df1.jpg'},
#    'measures': [{'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_serving',
#      'label': 'Serving',
#      'weight': 148.0},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_unit',
#      'label': 'Whole',
#      'weight': 151.0},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_bunch',
#      'label': 'Bunch',
#      'weight': 608.0},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_head',
#      'label': 'Head',
#      'weight': 608.0},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_branch',
#      'label': 'Branch',
#      'weight': 151.0},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_stalk',
#      'label': 'Stalk',
#      'weight': 151.0},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_stem',
#      'label': 'Stem',
#      'weight': 44.0},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_spear',
#      'label': 'Spear',
#      'weight': 31.0},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_gram',
#      'label': 'Gram',
#      'weight': 1.0},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_ounce',
#      'label': 'Ounce',
#      'weight': 28.349523125},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_pound',
#      'label': 'Pound',
#      'weight': 453.59237},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_kilogram',
#      'label': 'Kilogram',
#      'weight': 1000.0},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_cup',
#      'label': 'Cup',
#      'weight': 91.0,
#      'qualified': [{'qualifiers': [{'uri': 'http://www.edamam.com/ontologies/edamam.owl#Qualifier_chopped',
#          'label': 'chopped'}],
#        'weight': 91.0},
#       {'qualifiers': [{'uri': 'http://www.edamam.com/ontologies/edamam.owl#Qualifier_chopped',
#          'label': 'chopped'},
#         {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Qualifier_diced',
#          'label': 'diced'}],
#        'weight': 88.0}]}]},
#   {'food': {'foodId': 'food_blhjqxuagcrdf7bzsuuezbz813xc',
#     'label': 'Broccoli Raab',
#     'knownAs': 'broccoli raab',
#     'nutrients': {'ENERC_KCAL': 22.0,
#      'PROCNT': 3.17,
#      'FAT': 0.49,
#      'CHOCDF': 2.85,
#      'FIBTG': 2.7},
#     'category': 'Generic foods',
#     'categoryLabel': 'food',
#     'image': 'https://www.edamam.com/food-img/52a/52a2e62a7e6ca0963d1cab1f7cbc06f1.jpg'},
#    'measures': [{'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_serving',
#      'label': 'Serving',
#      'weight': 40.0},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_cup',
#      'label': 'Cup',
#      'weight': 40.0,
#      'qualified': [{'qualifiers': [{'uri': 'http://www.edamam.com/ontologies/edamam.owl#Qualifier_chopped',
#          'label': 'chopped'}],
#        'weight': 40.0}]},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_unit',
#      'label': 'Whole',
#      'weight': 19.0},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_bunch',
#      'label': 'Bunch',
#      'weight': 453.0},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_stalk',
#      'label': 'Stalk',
#      'weight': 19.0},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_gram',
#      'label': 'Gram',
#      'weight': 1.0},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_ounce',
#      'label': 'Ounce',
#      'weight': 28.349523125},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_pound',
#      'label': 'Pound',
#      'weight': 453.59237},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_kilogram',
#      'label': 'Kilogram',
#      'weight': 1000.0},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_handful',
#      'label': 'Handful',
#      'weight': 5.0}]},
#   {'food': {'foodId': 'food_bvq8864bioq3d5ar5ex1tb0qw3dr',
#     'label': 'Broccoli Stalk',
#     'knownAs': 'broccoli stalk',
#     'nutrients': {'ENERC_KCAL': 28.0,
#      'PROCNT': 2.98,
#      'FAT': 0.35,
#      'CHOCDF': 5.24},
#     'category': 'Generic foods',
#     'categoryLabel': 'food',
#     'image': 'https://www.edamam.com/food-img/f1a/f1ae69537c4e5970d5311923d2c696c4.jpeg'},
#    'measures': [{'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_unit',
#      'label': 'Whole',
#      'weight': 114.0},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_serving',
#      'label': 'Serving',
#      'weight': 114.0},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_stalk',
#      'label': 'Stalk',
#      'weight': 114.0},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_gram',
#      'label': 'Gram',
#      'weight': 1.0},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_ounce',
#      'label': 'Ounce',
#      'weight': 28.349523125},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_pound',
#      'label': 'Pound',
#      'weight': 453.59237},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_kilogram',
#      'label': 'Kilogram',
#      'weight': 1000.0}]},
#   {'food': {'foodId': 'food_b5r3hr9b7kn0jtaegq6pgbgyr034',
#     'label': 'Broccoli Flower',
#     'knownAs': 'broccoli florets',
#     'nutrients': {'ENERC_KCAL': 28.0,
#      'PROCNT': 2.98,
#      'FAT': 0.35,
#      'CHOCDF': 5.06,
#      'FIBTG': 2.3},
#     'category': 'Generic foods',
#     'categoryLabel': 'food',
#     'image': 'https://www.edamam.com/food-img/b11/b11b34a0dd535bf7aabeeb5413f24954.jpeg'},
#    'measures': [{'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_serving',
#      'label': 'Serving',
#      'weight': 71.0},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_cup',
#      'label': 'Cup',
#      'weight': 71.0},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_floweret',
#      'label': 'Floweret',
#      'weight': 11.0},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_gram',
#      'label': 'Gram',
#      'weight': 1.0},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_ounce',
#      'label': 'Ounce',
#      'weight': 28.349523125},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_pound',
#      'label': 'Pound',
#      'weight': 453.59237},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_kilogram',
#      'label': 'Kilogram',
#      'weight': 1000.0}]},
#   {'food': {'foodId': 'food_bjn5oefbluo0i9a991wrgbneulxg',
#     'label': 'Romanesco Broccoli',
#     'knownAs': 'romanesco',
#     'nutrients': {'ENERC_KCAL': 38.0,
#      'PROCNT': 4.0,
#      'FAT': 1.0,
#      'CHOCDF': 3.0,
#      'FIBTG': 2.0},
#     'category': 'Generic foods',
#     'categoryLabel': 'food',
#     'image': 'https://www.edamam.com/food-img/45d/45d2990b5ac50ff44e4d200c9e68e95f.jpg'},
#    'measures': [{'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_serving',
#      'label': 'Serving',
#      'weight': 54.0},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_unit',
#      'label': 'Whole',
#      'weight': 588.0},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_head',
#      'label': 'Head',
#      'weight': 588.0},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_gram',
#      'label': 'Gram',
#      'weight': 1.0},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_ounce',
#      'label': 'Ounce',
#      'weight': 28.349523125},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_pound',
#      'label': 'Pound',
#      'weight': 453.59237},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_kilogram',
#      'label': 'Kilogram',
#      'weight': 1000.0},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_cup',
#      'label': 'Cup',
#      'weight': 107.0}]},
#   {'food': {'foodId': 'food_bfcpa8papb5r7sbn7toa0aq769yp',
#     'label': 'Broccoli',
#     'knownAs': 'Broccoli',
#     'nutrients': {'ENERC_KCAL': 107.58727693705181,
#      'PROCNT': 5.1690449667143685,
#      'FAT': 6.085451679621292,
#      'CHOCDF': 9.079783063398084,
#      'FIBTG': 1.8404639152227362},
#     'category': 'Generic meals',
#     'categoryLabel': 'meal',
#     'foodContentsLabel': 'broccoli; butter; cream cheese; salt'},
#    'measures': [{'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_unit',
#      'label': 'Whole',
#      'weight': 225.5241141158517},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_serving',
#      'label': 'Serving',
#      'weight': 225.5241141158517},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_gram',
#      'label': 'Gram',
#      'weight': 1.0},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_ounce',
#      'label': 'Ounce',
#      'weight': 28.349523125},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_pound',
#      'label': 'Pound',
#      'weight': 453.59237},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_kilogram',
#      'label': 'Kilogram',
#      'weight': 1000.0},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_milliliter',
#      'label': 'Milliliter',
#      'weight': 1.0}]},
#   {'food': {'foodId': 'food_auwhv3qbogrjhpbld641ga7rlu67',
#     'label': 'Broccoli, Raw',
#     'knownAs': 'Broccoli, raw',
#     'nutrients': {'ENERC_KCAL': 34.0,
#      'PROCNT': 2.82,
#      'FAT': 0.37,
#      'CHOCDF': 6.64,
#      'FIBTG': 2.6},
#     'category': 'Generic foods',
#     'categoryLabel': 'food',
#     'image': 'https://www.edamam.com/food-img/3e4/3e47317a3dd54dc911b9c44122285df1.jpg'},
#    'measures': [{'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_serving',
#      'label': 'Serving',
#      'weight': 148.0},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_cup',
#      'label': 'Cup',
#      'weight': 91.0,
#      'qualified': [{'qualifiers': [{'uri': 'http://www.edamam.com/ontologies/edamam.owl#Qualifier_chopped',
#          'label': 'chopped'}],
#        'weight': 91.0},
#       {'qualifiers': [{'uri': 'http://www.edamam.com/ontologies/edamam.owl#Qualifier_chopped',
#          'label': 'chopped'},
#         {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Qualifier_diced',
#          'label': 'diced'}],
#        'weight': 88.0}]},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_head',
#      'label': 'Head',
#      'weight': 608.0},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_ounce',
#      'label': 'Ounce',
#      'weight': 28.349523125},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_pound',
#      'label': 'Pound',
#      'weight': 453.59237},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_unit',
#      'label': 'Whole',
#      'weight': 151.0},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_bunch',
#      'label': 'Bunch',
#      'weight': 608.0},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_gram',
#      'label': 'Gram',
#      'weight': 1.0},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_stalk',
#      'label': 'Stalk',
#      'weight': 151.0},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_stem',
#      'label': 'Stem',
#      'weight': 44.0},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_spear',
#      'label': 'Spear',
#      'weight': 31.0},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_kilogram',
#      'label': 'Kilogram',
#      'weight': 1000.0},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_branch',
#      'label': 'Branch',
#      'weight': 151.0}]},
#   {'food': {'foodId': 'food_a8kf63nau60sdyaatmxapa07isvi',
#     'label': 'Broccoli',
#     'knownAs': 'BROCCOLI',
#     'nutrients': {'ENERC_KCAL': 29.0,
#      'PROCNT': 3.5299999713897705,
#      'FAT': 0.0,
#      'CHOCDF': 4.710000038146973,
#      'FIBTG': 3.5},
#     'brand': 'Eat Smart',
#     'category': 'Packaged foods',
#     'categoryLabel': 'food',
#     'foodContentsLabel': 'BROCCOLI',
#     'servingSizes': [{'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_ounce',
#       'label': 'Ounce',
#       'quantity': 3.0},
#      {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_gram',
#       'label': 'Gram',
#       'quantity': 85.0}]},
#    'measures': [{'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_serving',
#      'label': 'Serving',
#      'weight': 85.048569375},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_gram',
#      'label': 'Gram',
#      'weight': 1.0},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_ounce',
#      'label': 'Ounce',
#      'weight': 28.349523125},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_pound',
#      'label': 'Pound',
#      'weight': 453.59237},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_kilogram',
#      'label': 'Kilogram',
#      'weight': 1000.0}]},
#   {'food': {'foodId': 'food_bnw0vckbx88pj4armqzt0anyhce7',
#     'label': 'Broccoli.',
#     'knownAs': 'BROCCOLI.',
#     'nutrients': {'ENERC_KCAL': 24.0,
#      'PROCNT': 2.3499999046325684,
#      'FAT': 0.0,
#      'CHOCDF': 4.710000038146973,
#      'FIBTG': 3.5},
#     'brand': 'Target Stores',
#     'category': 'Packaged foods',
#     'categoryLabel': 'food',
#     'foodContentsLabel': 'INGREDIENTS: BROCCOLI.',
#     'servingSizes': [{'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_gram',
#       'label': 'Gram',
#       'quantity': 85.0},
#      {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_cup',
#       'label': 'Cup',
#       'quantity': 0.75}]},
#    'measures': [{'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_serving',
#      'label': 'Serving',
#      'weight': 85.0},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_gram',
#      'label': 'Gram',
#      'weight': 1.0},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_ounce',
#      'label': 'Ounce',
#      'weight': 28.349523125},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_pound',
#      'label': 'Pound',
#      'weight': 453.59237},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_kilogram',
#      'label': 'Kilogram',
#      'weight': 1000.0},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_cup',
#      'label': 'Cup',
#      'weight': 113.33333333333333}]},
#   {'food': {'foodId': 'food_a4gvd3xarfhb0vb5tvuxkbvfpmd6',
#     'label': 'Kids Broccoli Littles, Broccoli',
#     'knownAs': 'KIDS BROCCOLI LITTLES, BROCCOLI',
#     'nutrients': {'ENERC_KCAL': 153.0,
#      'PROCNT': 3.5299999713897705,
#      'FAT': 8.239999771118164,
#      'CHOCDF': 16.469999313354492,
#      'FIBTG': 2.4000000953674316},
#     'brand': "Dr. Praeger's Sensible Foods, Inc.",
#     'category': 'Packaged foods',
#     'categoryLabel': 'food',
#     'foodContentsLabel': 'BROCCOLI; POTATOES; ONIONS; EXPELLER PRESSED CANOLA OIL; POTATO FLAKES; EGG WHITES; ARROWROOT POWDER; SEA SALT; GARLIC',
#     'image': 'https://www.edamam.com/food-img/d2e/d2efd7dce2371ddab229b4001ceb8ff8.jpg',
#     'servingSizes': [{'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_gram',
#       'label': 'Gram',
#       'quantity': 85.0}],
#     'servingsPerContainer': 9.0},
#    'measures': [{'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_serving',
#      'label': 'Serving',
#      'weight': 85.0},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_piece',
#      'label': 'Piece',
#      'weight': 42.5},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_package',
#      'label': 'Package',
#      'weight': 765.0},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_gram',
#      'label': 'Gram',
#      'weight': 1.0},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_ounce',
#      'label': 'Ounce',
#      'weight': 28.349523125},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_pound',
#      'label': 'Pound',
#      'weight': 453.59237},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_kilogram',
#      'label': 'Kilogram',
#      'weight': 1000.0}]},
#   {'food': {'foodId': 'food_b50jxojae2f537b3kxotobicn9wx',
#     'label': 'Broccoli au Gratin, Broccoli',
#     'knownAs': 'BROCCOLI AU GRATIN, BROCCOLI',
#     'nutrients': {'ENERC_KCAL': 105.0,
#      'PROCNT': 4.389999866485596,
#      'FAT': 6.139999866485596,
#      'CHOCDF': 7.889999866485596,
#      'FIBTG': 1.7999999523162842},
#     'brand': 'Publix Super Markets, Inc.',
#     'category': 'Packaged foods',
#     'categoryLabel': 'food',
#     'foodContentsLabel': 'BROCCOLI; WATER; CHEESE SPREAD (AMERICAN CHEESE [PASTEURIZED MILK; CHEESE CULTURES; SALT; ENZYMES]; WATER; WHEY; SODIUM PHOSPHATE; WHEY PROTEIN CONCENTRATE; SKIM MILK; SALT; MILK FAT; ANNATTO AND PAPRIKA EXTRACT [COLOR]); BUTTER BREADING (BREAD CRUMBS [ENRICHED BLEACHED WHEAT FLOUR {FLOUR; NIACIN; REDUCED IRON; THIAMINE MONONITRATE; RIBOFLAVIN; FOLIC ACID}; DISTILLED VINEGAR; VEGETABLE OIL {CANOLA AND/OR SOYBEAN AND/OR SUNFLOWER}; SALT; DEXTROSE; LEAVENING {SODIUM BICARBONATE}; EXTRACTIVES OF PAPRIKA AND ANNATTO {COLOR}; YEAST; CARAMEL COLOR; YEAST NUTRIENTS {AMMONIUM CHLORIDE; CALCIUM SULFATE}; SPICE EXTRACTIVE]; POWDERED BUTTER [BUTTER {CREAM; SALT; ANNATTO <COLOR>}; SKIM MILK; WHEY; SODIUM CASEINATE; BHA & BHT]; NATURAL BUTTER FLAVOR (WITH MALTODEXTRIN; NONFAT DRY MILK; NATURAL FLAVOR {WITH BUTTERFAT}; ANNATTO AND TURMERIC {COLOR}]',
#     'servingSizes': [{'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_gram',
#       'label': 'Gram',
#       'quantity': 114.0},
#      {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_cup',
#       'label': 'Cup',
#       'quantity': 0.5}]},
#    'measures': [{'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_serving',
#      'label': 'Serving',
#      'weight': 114.0},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_gram',
#      'label': 'Gram',
#      'weight': 1.0},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_ounce',
#      'label': 'Ounce',
#      'weight': 28.349523125},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_pound',
#      'label': 'Pound',
#      'weight': 453.59237},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_kilogram',
#      'label': 'Kilogram',
#      'weight': 1000.0},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_cup',
#      'label': 'Cup',
#      'weight': 228.0}]},
#   {'food': {'foodId': 'food_akh2r7qb405gfvbu2at4ibhrebiq',
#     'label': 'Broccoli Veggie Tots, Broccoli',
#     'knownAs': 'BROCCOLI VEGGIE TOTS, BROCCOLI',
#     'nutrients': {'ENERC_KCAL': 153.0,
#      'PROCNT': 3.5299999713897705,
#      'FAT': 8.239999771118164,
#      'CHOCDF': 16.469999313354492,
#      'FIBTG': 5.900000095367432},
#     'brand': 'B & G FOODS',
#     'category': 'Packaged foods',
#     'categoryLabel': 'food',
#     'foodContentsLabel': 'BROCCOLI; SOYBEAN OIL; MODIFIED FOOD STARCH; CORNSTARCH; WATER; CONTAINS LESS THAN 2% OF BAKING SODA; CITRIC ACID; DEXTRIN; DEXTROSE; DRIED EGGS; ENRICHED FLOUR (WHEAT FLOUR; NIACIN; REDUCED IRON; THIAMIN MONONITRATE; RIBOFLAVIN; FOLIC ACID); GARLIC POWDER; METHYLCELLULOSE; ONION POWDER; RICE FLOUR; SALT; SODIUM ACID PYROPHOSPHATE; SODIUM ALGINATE; SOY FLOUR; SPICES; SUGAR; WHEAT GLUTEN; WHEAT STARCH; WHEY; XANTHAN GUM; YELLOW CORN FLOUR.',
#     'image': 'https://www.edamam.com/food-img/f7c/f7c14b27ea19a9dae29b714257cc0983.png',
#     'servingSizes': [{'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_piece',
#       'label': 'Piece',
#       'quantity': 6.0},
#      {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_gram',
#       'label': 'Gram',
#       'quantity': 85.0}]},
#    'measures': [{'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_serving',
#      'label': 'Serving',
#      'weight': 85.0},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_piece',
#      'label': 'Piece',
#      'weight': 14.166666666666666},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_gram',
#      'label': 'Gram',
#      'weight': 1.0},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_ounce',
#      'label': 'Ounce',
#      'weight': 28.349523125},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_pound',
#      'label': 'Pound',
#      'weight': 453.59237},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_kilogram',
#      'label': 'Kilogram',
#      'weight': 1000.0}]},
#   {'food': {'foodId': 'food_bmnkda6aneo5xgbirbjb5acw1jyj',
#     'label': 'Broccoli Slaw Broccoli, Carrots & Red Cabbage, Broccoli Slaw',
#     'knownAs': 'BROCCOLI SLAW BROCCOLI, CARROTS & RED CABBAGE, BROCCOLI SLAW',
#     'nutrients': {'ENERC_KCAL': 35.0,
#      'PROCNT': 2.3499999046325684,
#      'FAT': 0.0,
#      'CHOCDF': 7.059999942779541,
#      'FIBTG': 2.4000000953674316},
#     'brand': 'Hy-Vee, Inc.',
#     'category': 'Packaged foods',
#     'categoryLabel': 'food',
#     'foodContentsLabel': 'BROCCOLI; CARROTS; RED CABBAGE.',
#     'servingSizes': [{'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_gram',
#       'label': 'Gram',
#       'quantity': 85.0},
#      {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_cup',
#       'label': 'Cup',
#       'quantity': 0.75}]},
#    'measures': [{'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_serving',
#      'label': 'Serving',
#      'weight': 85.0},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_gram',
#      'label': 'Gram',
#      'weight': 1.0},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_ounce',
#      'label': 'Ounce',
#      'weight': 28.349523125},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_pound',
#      'label': 'Pound',
#      'weight': 453.59237},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_kilogram',
#      'label': 'Kilogram',
#      'weight': 1000.0},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_cup',
#      'label': 'Cup',
#      'weight': 113.33333333333333}]},
#   {'food': {'foodId': 'food_a1apq8xauylei3b4c275sbpuyxm0',
#     'label': 'Broccoli Coleslaw Broccoli, Carrots and Red Cabbage, Broccoli Coleslaw',
#     'knownAs': 'BROCCOLI COLESLAW BROCCOLI, CARROTS AND RED CABBAGE, BROCCOLI COLESLAW',
#     'nutrients': {'ENERC_KCAL': 41.0,
#      'PROCNT': 2.3499999046325684,
#      'FAT': 0.0,
#      'CHOCDF': 7.059999942779541,
#      'FIBTG': 2.4000000953674316},
#     'brand': 'Safeway Inc.',
#     'category': 'Packaged foods',
#     'categoryLabel': 'food',
#     'foodContentsLabel': 'BROCCOLI STALK; CARROT; RED CABBAGE.',
#     'image': 'https://www.edamam.com/food-img/606/60684b46fd2eea050df9c2b282b208a1.jpg',
#     'servingSizes': [{'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_cup',
#       'label': 'Cup',
#       'quantity': 1.0},
#      {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_gram',
#       'label': 'Gram',
#       'quantity': 85.0}]},
#    'measures': [{'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_serving',
#      'label': 'Serving',
#      'weight': 85.0},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_cup',
#      'label': 'Cup',
#      'weight': 85.0},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_gram',
#      'label': 'Gram',
#      'weight': 1.0},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_ounce',
#      'label': 'Ounce',
#      'weight': 28.349523125},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_pound',
#      'label': 'Pound',
#      'weight': 453.59237},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_kilogram',
#      'label': 'Kilogram',
#      'weight': 1000.0}]},
#   {'food': {'foodId': 'food_awa3vvfb20beoub7k8hu2bszsikw',
#     'label': 'Beef & Broccoli, Beef & Broccoli',
#     'knownAs': 'BEEF & BROCCOLI, BEEF & BROCCOLI',
#     'nutrients': {'ENERC_KCAL': 132.0,
#      'PROCNT': 7.940000057220459,
#      'FAT': 4.760000228881836,
#      'CHOCDF': 15.869999885559082,
#      'FIBTG': 1.600000023841858},
#     'brand': 'The Moran Group Incorporated',
#     'category': 'Packaged foods',
#     'categoryLabel': 'food',
#     'foodContentsLabel': 'BROCCOLI FLORETS; FULLY COOKED SEASONED BEEF STRIPS WITH WATER AND BINDER PRODUCT (BEEF; WATER; VINEGAR; RICE FLOUR; RICE STARCH; TAPIOCA STARCH; SODIUM BICARBONATE; SEA SALT. COOKED IN VEGETABLE OIL); GOURMET SOY SAUCE: WATER; OYSTER SAUCE (WATER; SUGAR; OYSTER EXTRACT; SALT; SOYBEAN; CORN FLOUR; HYDROLYZED VEGETABLE PROTEIN; MONOSODIUM GLUTAMATE; DISODIUM GUANYLATE; DISODIUM INOSINATE); CARAMEL ACETIC ACID; CORN FLOUR; SUGAR; SOY SAUCE (SOYBEAN EXTRACT [WATER; SOYBEANS; WHEAT; SALT]; MOLASSES; CARAMEL; ACIDIFYING AGENTS); CORN STARCH; SALT; SEASONING POWDER (WHEAT FLOUR; SUGAR; CORN FLOUR; IODIZED SALT; MILK SOLIDS; DEHYDRATED VEGETABLE [ONION; GARLICI]; YEAST EXTRACT; WHITE PEPPER; ASCORBIC ACID; MALIC ACID; GUAR GUM); DEMIGLAZE POWDER (DEHYDRATED ONION; WHEAT FLOUR; IODIZED SALT; SOY SAUCE POWDER; MONOSODIUM GLUTAMATE; SUGAR; CHICKEN MEAT POWDER; THICKENING AGENTS [GUAR GUM; MODIFIED FOOD STARCH]; GARLIC; SESAME OIL; VINEGAR; SUNFLOWER OIL; DEHYDRATED ONION AND GARLIC; GUAR GUM; BLACK PEPPER; CHILI POWDER).',
#     'servingSizes': [{'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_cup',
#       'label': 'Cup',
#       'quantity': 1.0},
#      {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_gram',
#       'label': 'Gram',
#       'quantity': 189.0}]},
#    'measures': [{'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_serving',
#      'label': 'Serving',
#      'weight': 189.0},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_cup',
#      'label': 'Cup',
#      'weight': 189.0},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_gram',
#      'label': 'Gram',
#      'weight': 1.0},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_ounce',
#      'label': 'Ounce',
#      'weight': 28.349523125},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_pound',
#      'label': 'Pound',
#      'weight': 453.59237},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_kilogram',
#      'label': 'Kilogram',
#      'weight': 1000.0}]},
#   {'food': {'foodId': 'food_a50jfh2bn7tvj2atq9jhiau4dnjb',
#     'label': 'Broccoli Carbonara',
#     'knownAs': 'Broccoli Carbonara',
#     'nutrients': {'ENERC_KCAL': 186.23500634876248,
#      'PROCNT': 7.66473115648674,
#      'FAT': 8.738051043196405,
#      'CHOCDF': 19.802859091061375,
#      'FIBTG': 2.0135181219059404},
#     'category': 'Generic meals',
#     'categoryLabel': 'meal',
#     'foodContentsLabel': 'broccoli; garlic; pecorino; extra virgin olive oil; cream; eggs; spaghettoni; bacon; Broccoli florets'},
#    'measures': [{'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_unit',
#      'label': 'Whole',
#      'weight': 408.76202352404397},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_serving',
#      'label': 'Serving',
#      'weight': 408.76202352404397},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_gram',
#      'label': 'Gram',
#      'weight': 1.0},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_ounce',
#      'label': 'Ounce',
#      'weight': 28.349523125},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_pound',
#      'label': 'Pound',
#      'weight': 453.59237},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_kilogram',
#      'label': 'Kilogram',
#      'weight': 1000.0},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_milliliter',
#      'label': 'Milliliter',
#      'weight': 1.0}]},
#   {'food': {'foodId': 'food_a9uzr9faeshko0bwsow0ebsxuvdu',
#     'label': 'Shrimp and Broccoli',
#     'knownAs': 'Shrimp And Broccoli',
#     'nutrients': {'ENERC_KCAL': 81.10295403860168,
#      'PROCNT': 8.59892495570981,
#      'FAT': 1.9435848199374424,
#      'CHOCDF': 7.753721021813219,
#      'FIBTG': 0.9068060243416833},
#     'category': 'Generic meals',
#     'categoryLabel': 'meal',
#     'foodContentsLabel': 'Shrimp; Lemons; Broccoli; Salt; Pepper'},
#    'measures': [{'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_unit',
#      'label': 'Whole',
#      'weight': 316.0050251523107},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_serving',
#      'label': 'Serving',
#      'weight': 316.0050251523107},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_gram',
#      'label': 'Gram',
#      'weight': 1.0},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_ounce',
#      'label': 'Ounce',
#      'weight': 28.349523125},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_pound',
#      'label': 'Pound',
#      'weight': 453.59237},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_kilogram',
#      'label': 'Kilogram',
#      'weight': 1000.0},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_milliliter',
#      'label': 'Milliliter',
#      'weight': 1.0}]},
#   {'food': {'foodId': 'food_bvrvdbcb76mk75a867bxba57gf3k',
#     'label': 'Broccoli Almondine',
#     'knownAs': 'Broccoli Almondine',
#     'nutrients': {'ENERC_KCAL': 102.2692198095274,
#      'PROCNT': 3.3170541943919716,
#      'FAT': 7.877687166348299,
#      'CHOCDF': 6.800423247610657,
#      'FIBTG': 2.7762006579458838},
#     'category': 'Generic meals',
#     'categoryLabel': 'meal',
#     'foodContentsLabel': 'almonds; broccoli; lemon juice; unsalted butter'},
#    'measures': [{'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_unit',
#      'label': 'Whole',
#      'weight': 194.32620254683053},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_serving',
#      'label': 'Serving',
#      'weight': 194.32620254683053},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_gram',
#      'label': 'Gram',
#      'weight': 1.0},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_ounce',
#      'label': 'Ounce',
#      'weight': 28.349523125},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_pound',
#      'label': 'Pound',
#      'weight': 453.59237},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_kilogram',
#      'label': 'Kilogram',
#      'weight': 1000.0},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_milliliter',
#      'label': 'Milliliter',
#      'weight': 1.0}]},
#   {'food': {'foodId': 'food_bjko7txb738g6ra5k8js6absjz1n',
#     'label': 'Italian Broccoli',
#     'knownAs': 'Italian Broccoli',
#     'nutrients': {'ENERC_KCAL': 109.78789204397724,
#      'PROCNT': 3.7597693271205848,
#      'FAT': 8.266235121371503,
#      'CHOCDF': 6.5874563567580156,
#      'FIBTG': 2.1104423611018976},
#     'category': 'Generic meals',
#     'categoryLabel': 'meal',
#     'foodContentsLabel': 'broccoli; water; Diced Tomatoes; mozzarella cheese'},
#    'measures': [{'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_unit',
#      'label': 'Whole',
#      'weight': 161.39722171800972},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_serving',
#      'label': 'Serving',
#      'weight': 161.39722171800972},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_gram',
#      'label': 'Gram',
#      'weight': 1.0},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_ounce',
#      'label': 'Ounce',
#      'weight': 28.349523125},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_pound',
#      'label': 'Pound',
#      'weight': 453.59237},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_kilogram',
#      'label': 'Kilogram',
#      'weight': 1000.0},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_bowl',
#      'label': 'Bowl',
#      'weight': 140.6585789},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_milliliter',
#      'label': 'Milliliter',
#      'weight': 1.0}]},
#   {'food': {'foodId': 'food_bps6qk6aiui6gnaihzwnmbrb514w',
#     'label': 'Broccoli Mash',
#     'knownAs': 'Broccoli Mash',
#     'nutrients': {'ENERC_KCAL': 62.29710508634541,
#      'PROCNT': 3.0945937826739667,
#      'FAT': 3.0448027032110145,
#      'CHOCDF': 7.286951749521812,
#      'FIBTG': 2.326022573710716},
#     'category': 'Generic meals',
#     'categoryLabel': 'meal',
#     'foodContentsLabel': 'Broccoli; romano; Butter; Cream; Salt; Pepper'},
#    'measures': [{'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_unit',
#      'label': 'Whole',
#      'weight': 215.2949846793838},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_serving',
#      'label': 'Serving',
#      'weight': 215.2949846793838},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_gram',
#      'label': 'Gram',
#      'weight': 1.0},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_ounce',
#      'label': 'Ounce',
#      'weight': 28.349523125},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_pound',
#      'label': 'Pound',
#      'weight': 453.59237},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_kilogram',
#      'label': 'Kilogram',
#      'weight': 1000.0},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_milliliter',
#      'label': 'Milliliter',
#      'weight': 1.0}]}],
#  '_links': {'next': {'href': 'https://api.edamam.com/api/food-database/v2/parser?session=CHcDEWgRY0lhWBENQWVcETMBaVU-&app_id=8880ad1c&app_key=de0f3ec5555c833ebc56d2741f107fa7&ingr=broccoli',
#    'title': 'Next page'}}}

# %% [markdown]
# ## Data Collection Pipeline
#
# **Extract from Edamam API - Setup and Data Retrieval**
# - Set up API client with proper error handling
# - Define what fields you need from the API
# - Implement rate limiting and pagination
# - Basic validation of API responses
#
# **Store Raw Data in PostgreSQL - Database Setup and Data Storage**
# - Create `raw_recipes` table with JSONB column
# - Set up database connection
# - Implement batch inserts for efficiency
# - Add metadata (timestamp, source, etc.)
#
# **Clean and Transform - Data Preprocessing and Validation**
# - Parse ingredient strings
# - Normalize units
# - Standardize nutritional values
# - Remove duplicates
# - Validate data quality (your embedding-based checks)
# - Handle missing values
#
# **Store Cleaned Data - Normalized Data Storage**
# - Create normalized table schema (recipes, ingredients, nutritional_facts)
# - Implement foreign key relationships
# - Store with references to raw data
# - Add indexes for common queries
#
# **Additional Considerations**
# - Add logging throughout the pipeline
# - Implement error handling for each step
# - Add basic data quality metrics
# - Make the pipeline idempotent (can safely re-run)
#
# Note: later we can also create embeddings for data quality checks (embed ingredient lists and do semantic search with LLM output to find similar recipes. Use a threshold - if there is no recipe similar to it then the LLM output may not be good). Also, use embeddings to find similar recipe names, which can be given to another LLM prompt to generate the most relevant one.

# %%
import os
import requests
import pandas as pd

edamam_api_id = os.environ["EDAMAM_API_ID"]
edamam_api_key = os.environ["EDAMAM_API_KEY"]

# %% [markdown]
# Note that this is the version 2 of the EDAMAM API.

# %%
def get_recipes(query='*', from_index=0, to_index=10):
    app_id = edamam_api_id
    app_key = edamam_api_key
    
    params = {
        'type': 'public',
        'app_id': app_id,
        'app_key': app_key,
        'q': query,
        'imageSize': 'THUMBNAIL',
        'random': 'true',
        'field': [
            'label',                # Recipe name
            'ingredientLines',      # List of ingredients
            'ingredients',          # Detailed ingredient info
            'calories',            
            'totalNutrients',       # Detailed nutrition
            'totalWeight',
            'dietLabels',
            'healthLabels',
            'cuisineType',
            'mealType',
            'dishType',
            'yield',               # Number of servings
            'totalTime',           # Cooking time
            'instructions',        # Cooking steps
            'source',              # Recipe source
            'uri',                 # Unique identifier
            'images'               # Recipe images
        ]
    }
    
    response = requests.get('https://api.edamam.com/api/recipes/v2', params=params)
    data = response.json()
    return data['hits'] if 'hits' in data else []

# %%
sample_recipes = get_recipes()

# %%
sample_recipes[0].keys()
# Out:
# dict_keys(['recipe', '_links'])

# %%
sample_recipes[0]['recipe'].keys()
# Out:
# dict_keys(['uri', 'label', 'images', 'source', 'yield', 'dietLabels', 'healthLabels', 'ingredientLines', 'ingredients', 'calories', 'totalWeight', 'totalTime', 'cuisineType', 'mealType', 'dishType', 'totalNutrients'])

# %%
sample_recipes[0]['recipe']['healthLabels']
# Out:
# ['Low Potassium',
#  'Kidney-Friendly',
#  'Vegetarian',
#  'Pescatarian',
#  'Peanut-Free',
#  'Tree-Nut-Free',
#  'Soy-Free',
#  'Fish-Free',
#  'Shellfish-Free',
#  'Pork-Free',
#  'Red-Meat-Free',
#  'Crustacean-Free',
#  'Celery-Free',
#  'Mustard-Free',
#  'Sesame-Free',
#  'Lupine-Free',
#  'Mollusk-Free',
#  'Kosher']

# %% [markdown]
# The totalNutrients dictionary contains all the nutritional information for the recipe, including macronutrients that we are interested in.

# %%
sample_recipes[0]['recipe']['totalNutrients']
# Out:
# {'ENERC_KCAL': {'label': 'Energy', 'quantity': 3669.086688, 'unit': 'kcal'},
#  'FAT': {'label': 'Fat', 'quantity': 218.9987755, 'unit': 'g'},
#  'FASAT': {'label': 'Saturated', 'quantity': 130.19909093, 'unit': 'g'},
#  'FATRN': {'label': 'Trans', 'quantity': 0.04902, 'unit': 'g'},
#  'FAMS': {'label': 'Monounsaturated', 'quantity': 67.1051496445, 'unit': 'g'},
#  'FAPU': {'label': 'Polyunsaturated',
#   'quantity': 10.273119147100001,
#   'unit': 'g'},
#  'CHOCDF': {'label': 'Carbs', 'quantity': 417.197362215, 'unit': 'g'},
#  'CHOCDF.net': {'label': 'Carbohydrates (net)',
#   'quantity': 400.4413873,
#   'unit': 'g'},
#  'FIBTG': {'label': 'Fiber', 'quantity': 16.755974915000003, 'unit': 'g'},
#  'SUGAR': {'label': 'Sugars', 'quantity': 295.17462082500003, 'unit': 'g'},
#  'SUGAR.added': {'label': 'Sugars, added',
#   'quantity': 293.728920825,
#   'unit': 'g'},
#  'PROCNT': {'label': 'Protein', 'quantity': 40.73118977, 'unit': 'g'},
#  'CHOLE': {'label': 'Cholesterol',
#   'quantity': 844.3050000000001,
#   'unit': 'mg'},
#  'NA': {'label': 'Sodium', 'quantity': 1419.7025803499998, 'unit': 'mg'},
#  'CA': {'label': 'Calcium', 'quantity': 271.3537792, 'unit': 'mg'},
#  'MG': {'label': 'Magnesium', 'quantity': 321.37261275, 'unit': 'mg'},
#  'K': {'label': 'Potassium', 'quantity': 1317.21307525, 'unit': 'mg'},
#  'FE': {'label': 'Iron', 'quantity': 15.793570590499998, 'unit': 'mg'},
#  'ZN': {'label': 'Zinc', 'quantity': 6.416998197, 'unit': 'mg'},
#  'P': {'label': 'Phosphorus', 'quantity': 750.2549642000001, 'unit': 'mg'},
#  'VITA_RAE': {'label': 'Vitamin A',
#   'quantity': 1365.7800000000002,
#   'unit': 'µg'},
#  'VITC': {'label': 'Vitamin C', 'quantity': 0.0, 'unit': 'mg'},
#  'THIA': {'label': 'Thiamin (B1)',
#   'quantity': 1.1724649017500002,
#   'unit': 'mg'},
#  'RIBF': {'label': 'Riboflavin (B2)', 'quantity': 1.5214665665, 'unit': 'mg'},
#  'NIA': {'label': 'Niacin (B3)', 'quantity': 9.21840370995, 'unit': 'mg'},
#  'VITB6A': {'label': 'Vitamin B6',
#   'quantity': 0.44422866475000006,
#   'unit': 'mg'},
#  'FOLDFE': {'label': 'Folate equivalent (total)',
#   'quantity': 466.80150405,
#   'unit': 'µg'},
#  'FOLFD': {'label': 'Folate (food)', 'quantity': 139.30150405, 'unit': 'µg'},
#  'FOLAC': {'label': 'Folic acid', 'quantity': 192.5, 'unit': 'µg'},
#  'VITB12': {'label': 'Vitamin B12', 'quantity': 1.46001, 'unit': 'µg'},
#  'VITD': {'label': 'Vitamin D', 'quantity': 2.58, 'unit': 'µg'},
#  'TOCPHA': {'label': 'Vitamin E', 'quantity': 6.164070081, 'unit': 'mg'},
#  'VITK1': {'label': 'Vitamin K', 'quantity': 25.32758636, 'unit': 'µg'},
#  'WATER': {'label': 'Water', 'quantity': 254.722273295, 'unit': 'g'}}

# %% [markdown]
# In order to collect a diverse dataset, we should query for all recipes with combinations of the various fields/metadata available to us. More specifically, we should be able to query for all recipes that have a certain cuisine type, meal type, dish type, etc.
#
# The different values we can search for, per metadata, are things you can find in the documentation. Lists of each are below.
#
# Also some things to note: label is the meal name, totalTime is in minutes, calories are in kcal, yield is number of servings, and

# %%
diet_labels = [
    "balanced",      # Protein/Fat/Carb values in 15/35/50 ratio
    "high-fiber",    # More than 5g fiber per serving
    "high-protein",  # More than 50% of total calories from proteins
    "low-carb",      # Less than 20% of total calories from carbs
    "low-fat",       # Less than 15% of total calories from fat
    "low-sodium"     # Less than 140mg Na per serving
]

# %%
health_labels = [
    "alcohol-cocktail",    # Describes an alcoholic cocktail
    "alcohol-free",        # No alcohol used or contained
    "celery-free",        # Does not contain celery or derivatives
    "crustacean-free",    # Does not contain crustaceans
    "dairy-free",         # No dairy; no lactose
    "DASH",               # Dietary Approaches to Stop Hypertension diet
    "egg-free",           # No eggs or products containing eggs
    "fish-free",          # No fish or fish derivatives
    "fodmap-free",        # Does not contain FODMAP foods
    "gluten-free",        # No ingredients containing gluten
    "immuno-supportive",  # Science-based immune system strengthening
    "keto-friendly",      # Maximum 7 grams of net carbs per serving
    "kidney-friendly",    # Restricted phosphorus, potassium, and sodium
    "kosher",             # Contains only kosher-allowed ingredients
    "low-potassium",      # Less than 150mg per serving
    "low-sugar",          # No simple sugars
    "lupine-free",        # Does not contain lupine or derivatives
    "Mediterranean",      # Mediterranean diet
    "mollusk-free",       # No mollusks
    "mustard-free",       # Does not contain mustard or derivatives
    "No-oil-added",       # No oil added except in basic ingredients
    "paleo",              # Excludes agricultural products
    "peanut-free",        # No peanuts or products containing peanuts
    "pecatarian",         # No meat, can contain dairy and fish
    "pork-free",          # Does not contain pork or derivatives
    "red-meat-free",      # No red meat or products containing red meat
    "sesame-free",        # Does not contain sesame seed or derivatives
    "shellfish-free",     # No shellfish or shellfish derivatives
    "soy-free",           # No soy or products containing soy
    "sugar-conscious",    # Less than 4g of sugar per serving
    "sulfite-free",       # No Sulfites
    "tree-nut-free",      # No tree nuts or products containing tree nuts
    "vegan",              # No animal products
    "vegetarian",         # No meat, poultry, or fish
    "wheat-free"          # No wheat, can have gluten though
]

# %%
meal_types = [
    "breakfast",
    "brunch",
    "lunch", # lunch/dinner are the same according to the API, so we only need one of these labels
    "snack",
    "teatime"
]

# %%
dish_types = [
    "alcohol cocktail",
    "biscuits and cookies",
    "bread",
    "cereals",
    "condiments and sauces",
    "desserts",
    "drinks",
    "egg",
    "ice cream and custard",
    "main course",
    "pancake",
    "pasta",
    "pastry",
    "pies and tarts",
    "pizza",
    "preps",
    "preserve",
    "salad",
    "sandwiches",
    "seafood",
    "side dish",
    "soup",
    "special occasions",
    "starter",
    "sweets"
]

# %%
cuisine_types = [
    "american",
    "asian",
    "british",
    "caribbean",
    "central europe",
    "chinese",
    "eastern europe",
    "french",
    "greek",
    "indian",
    "italian",
    "japanese",
    "korean",
    "kosher",
    "mediterranean",
    "mexican",
    "middle eastern",
    "nordic",
    "south american",
    "south east asian",
    "world" # International cuisine/Other
]

# %%
def get_recipes(diet_labels, health_labels, meal_types, dish_types, cuisine_types, query='*', from_index=0, to_index=1000):
    app_id = edamam_api_id
    app_key = edamam_api_key
    
    params = {
        'type': 'public',
        'app_id': app_id,
        'app_key': app_key,
        'q': query,
        'imageSize': 'THUMBNAIL',
        'random': 'true',
        'field': [
            'label',               
            'ingredientLines',     
            'ingredients',         
            'totalNutrients',      
            'totalWeight',
            'dietLabels',
            'healthLabels',
            'cuisineType',
            'mealType',
            'dishType',
            'yield',              
            'totalTime',           
            'source',              
            'uri',                
            'images'               
        ]
    }
    
    # Only add parameters if they're not empty
    if diet_labels:
        params['diet'] = diet_labels if isinstance(diet_labels, list) else [diet_labels]
    if health_labels:
        params['health'] = health_labels if isinstance(health_labels, list) else [health_labels]
    if meal_types:
        params['mealType'] = meal_types if isinstance(meal_types, list) else [meal_types]
    if dish_types:
        params['dishType'] = dish_types if isinstance(dish_types, list) else [dish_types]
    if cuisine_types:
        params['cuisineType'] = cuisine_types if isinstance(cuisine_types, list) else [cuisine_types]
    
    response = requests.get('https://api.edamam.com/api/recipes/v2', params=params)
    
    # Debug information
    print(f"URL: {response.url}")
    print(f"Status Code: {response.status_code}")
    print(f"Response: {response.json()}")
    
    data = response.json()
    return data['hits'] if 'hits' in data else []

# Try with a single parameter first to isolate issues
sample_recipes = get_recipes(
    diet_labels=['balanced'],
    health_labels=['egg-free'],
    meal_types=['dinner'],
    dish_types=['salad'],
    cuisine_types=['american']
)
# Out:
# URL: https://api.edamam.com/api/recipes/v2?type=public&app_id=213b4d83&app_key=eb0bcd72cc7e2adc795cca5d7b6b4b37&q=%2A&imageSize=THUMBNAIL&random=true&field=label&field=ingredientLines&field=ingredients&field=totalNutrients&field=totalWeight&field=dietLabels&field=healthLabels&field=cuisineType&field=mealType&field=dishType&field=yield&field=totalTime&field=source&field=uri&field=images&diet=balanced&health=egg-free&mealType=dinner&dishType=salad&cuisineType=american
# Status Code: 200
# Response: {'from': 1, 'to': 20, 'count': 2789, '_links': {}, 'hits': [{'recipe': {'uri': 'http://www.edamam.com/ontologies/edamam.owl#recipe_620c4f9adcb7509cbfbb6828ce8fc679', 'label': 'Lime Salad Spritz', 'images': {'THUMBNAIL': {'url': 'https://www.edamam.com/web-img/not-found.jpg', 'width': 100, 'height': 100}, 'SMALL': {'url': 'https://www.edamam.com/web-img/not-found.jpg', 'width': 200, 'height': 200}, 'REGULAR': {'url': 'https://www.edamam.com/web-img/not-found.jpg', 'width': 300, 'height': 300}}, 'source': 'food.com', 'yield': 2.0, 'dietLabels': ['Balanced', 'Low-Sodium'], 'healthLabels': ['Sugar-Conscious', 'Low Potassium', 'Kidney-Friendly', 'Keto-Friendly', 'Vegetarian', 'Pescatarian', 'Mediterranean', 'Gluten-Free', 'Wheat-Free', 'Egg-Free', 'Peanut-Free', 'Tree-Nut-Free', 'Soy-Free', 'Fish-Free', 'Shellfish-Free', 'Pork-Free', 'Red-Meat-Free', 'Crustacean-Free', 'Celery-Free', 'Sesame-Free', 'Lupine-Free', 'Mollusk-Free', 'Alcohol-Free', 'No oil added', 'Sulfite-Free', 'Kosher'], 'ingredientLines': ['1⁄4 cup plain yogurt', '6 tablespoons fresh lime juice', '2 teaspoons lime zest, minced', '2 teaspoons horseradish', '2 teaspoons dijon-style mustard', '2 tablespoons white wine vinegar', 'fresh ground black pepper'], 'ingredients': [{'text': '1⁄4 cup plain yogurt', 'quantity': 0.25, 'measure': 'cup', 'food': 'plain yogurt', 'weight': 61.25, 'foodCategory': 'yogurt', 'foodId': 'food_a79ojfkbgdeekgblqmky9bunr8f6', 'image': 'https://www.edamam.com/food-img/933/933eb3791b3a2175e007f1607d56b7e2.jpg'}, {'text': '6 tablespoons fresh lime juice', 'quantity': 6.0, 'measure': 'tablespoon', 'food': 'lime juice', 'weight': 92.39999999843779, 'foodCategory': 'fruit', 'foodId': 'food_b0iywbmaujvd4eblrooo9bsvn7e6', 'image': 'https://www.edamam.com/food-img/8f0/8f0c10eb3dbf476a05e61018e76ea220.jpg'}, {'text': '2 teaspoons lime zest, minced', 'quantity': 2.0, 'measure': 'teaspoon', 'food': 'lime zest', 'weight': 4.0, 'foodCategory': 'fruit', 'foodId': 'food_bpg66j3a5vjuuga36uiiyaqeazpd', 'image': 'https://www.edamam.com/food-img/540/5405605c8e9b284243f06c0b1587ab6f.jpg'}, {'text': '2 teaspoons horseradish', 'quantity': 2.0, 'measure': 'teaspoon', 'food': 'horseradish', 'weight': 10.0, 'foodCategory': 'Condiments and sauces', 'foodId': 'food_bt10wq1burha64az05cdka9pweff', 'image': 'https://www.edamam.com/food-img/cc8/cc83e12eb36bdcc3015201c1cfac8656.jpg'}, {'text': '2 teaspoons dijon-style mustard', 'quantity': 2.0, 'measure': 'teaspoon', 'food': 'mustard', 'weight': 10.0, 'foodCategory': 'Condiments and sauces', 'foodId': 'food_a34cdj5b0kyuhfbov30xcb50u4dv', 'image': 'https://www.edamam.com/food-img/e23/e238f2e4cfa6aa1a30f46dc73e7344eb.jpg'}, {'text': '2 tablespoons white wine vinegar', 'quantity': 2.0, 'measure': 'tablespoon', 'food': 'white wine vinegar', 'weight': 29.8, 'foodCategory': 'Condiments and sauces', 'foodId': 'food_ai77igmb8f0rj6blsokr8bxx5n2n', 'image': 'https://www.edamam.com/food-img/5f6/5f69b84c399d778c4728e9ab4f8065a2.jpg'}, {'text': 'fresh ground black pepper', 'quantity': 0.0, 'measure': None, 'food': 'black pepper', 'weight': 0.6223499999953135, 'foodCategory': 'Condiments and sauces', 'foodId': 'food_b6ywzluaaxv02wad7s1r9ag4py89', 'image': 'https://www.edamam.com/food-img/c6e/c6e5c3bd8d3bc15175d9766971a4d1b2.jpg'}], 'totalWeight': 208.07234999843314, 'totalTime': 5.0, 'cuisineType': ['american'], 'mealType': ['lunch/dinner'], 'dishType': ['salad'], 'totalNutrients': {'ENERC_KCAL': {'label': 'Energy', 'quantity': 80.0685984995977, 'unit': 'kcal'}, 'FAT': {'label': 'Fat', 'quantity': 2.490593609998754, 'unit': 'g'}, 'FASAT': {'label': 'Saturated', 'quantity': 1.33425266499981, 'unit': 'g'}, 'FATRN': {'label': 'Trans', 'quantity': 0.0009, 'unit': 'g'}, 'FAMS': {'label': 'Monounsaturated', 'quantity': 0.7903936664998406, 'unit': 'g'}, 'FAPU': {'label': 'Polyunsaturated', 'quantity': 0.19867305299959392, 'unit': 'g'}, 'CHOCDF': {'label': 'Carbs', 'quantity': 13.397553999865465, 'unit': 'g'}, 'CHOCDF.net': {'label': ' ...

# %%
len(sample_recipes)
# Out:
# 20

# %%
sample_recipes[0]['recipe']['mealType']
# Out:
# ['lunch/dinner']

# %% [markdown]
# Testing out another example.

# %%
sample_recipes_2 = get_recipes(
    diet_labels=['balanced'],
    health_labels=['sugar-conscious'],
    meal_types=['breakfast'],
    dish_types=['egg'],
    cuisine_types=['american']
)
len(sample_recipes_2)
# Out:
# URL: https://api.edamam.com/api/recipes/v2?type=public&app_id=213b4d83&app_key=eb0bcd72cc7e2adc795cca5d7b6b4b37&q=%2A&imageSize=THUMBNAIL&random=true&field=label&field=ingredientLines&field=ingredients&field=totalNutrients&field=totalWeight&field=dietLabels&field=healthLabels&field=cuisineType&field=mealType&field=dishType&field=yield&field=totalTime&field=source&field=uri&field=images&diet=balanced&health=sugar-conscious&mealType=breakfast&dishType=egg&cuisineType=american
# Status Code: 200
# Response: {'from': 1, 'to': 9, 'count': 9, '_links': {}, 'hits': [{'recipe': {'uri': 'http://www.edamam.com/ontologies/edamam.owl#recipe_149fd7fcf00a4ec1904359195733dcfd', 'label': 'Arepas de Huevo (Egg-Stuffed Corn Cakes)', 'images': {'THUMBNAIL': {'url': 'https://www.edamam.com/web-img/not-found.jpg', 'width': 100, 'height': 100}, 'SMALL': {'url': 'https://www.edamam.com/web-img/not-found.jpg', 'width': 200, 'height': 200}, 'REGULAR': {'url': 'https://www.edamam.com/web-img/not-found.jpg', 'width': 300, 'height': 300}, 'LARGE': {'url': 'https://www.edamam.com/web-img/not-found.jpg', 'width': 600, 'height': 600}}, 'source': 'Saveur', 'yield': 8.0, 'dietLabels': ['Balanced'], 'healthLabels': ['Sugar-Conscious', 'Low Potassium', 'Kidney-Friendly', 'Vegetarian', 'Pescatarian', 'Mediterranean', 'Dairy-Free', 'Gluten-Free', 'Wheat-Free', 'Peanut-Free', 'Tree-Nut-Free', 'Soy-Free', 'Fish-Free', 'Shellfish-Free', 'Pork-Free', 'Red-Meat-Free', 'Crustacean-Free', 'Celery-Free', 'Mustard-Free', 'Sesame-Free', 'Lupine-Free', 'Mollusk-Free', 'Alcohol-Free', 'Sulfite-Free', 'Kosher'], 'ingredientLines': ['2 cups precooked white corn flour, preferably Harina P.A.N.', '1 1⁄2 tsp. kosher salt', '1 tbsp. canola oil, plus more for frying', '8 eggs', 'Hot sauce, for serving (optional)'], 'ingredients': [{'text': '2 cups precooked white corn flour, preferably Harina P.A.N.', 'quantity': 2.0, 'measure': 'cup', 'food': 'corn flour', 'weight': 228.0, 'foodCategory': 'grains', 'foodId': 'food_b2kpkh4acfeyuoaktkafwbjq55r7', 'image': 'https://www.edamam.com/food-img/95a/95a2e8b91ba3a3c42c36ae1a541782e8.jpg'}, {'text': '1 1⁄2 tsp. kosher salt', 'quantity': 1.5, 'measure': 'teaspoon', 'food': 'kosher salt', 'weight': 7.2812500003693135, 'foodCategory': 'Condiments and sauces', 'foodId': 'food_a1vgrj1bs8rd1majvmd9ubz8ttkg', 'image': 'https://www.edamam.com/food-img/694/6943ea510918c6025795e8dc6e6eaaeb.jpg'}, {'text': '1 tbsp. canola oil, plus more for frying', 'quantity': 1.0, 'measure': 'tablespoon', 'food': 'canola oil', 'weight': 14.0, 'foodCategory': 'Oils', 'foodId': 'food_bk9p9aaavhvoq4bqsnprobpsiuxs', 'image': 'https://www.edamam.com/food-img/07e/07e106ab3536d57428e5c46d009038f8.jpg'}, {'text': '8 eggs', 'quantity': 8.0, 'measure': '<unit>', 'food': 'eggs', 'weight': 344.0, 'foodCategory': 'Eggs', 'foodId': 'food_bhpradua77pk16aipcvzeayg732r', 'image': 'https://www.edamam.com/food-img/a7e/a7ec7c337cb47c6550b3b118e357f077.jpg'}, {'text': 'Hot sauce, for serving (optional)', 'quantity': 1.0, 'measure': 'serving', 'food': 'Hot sauce', 'weight': 6.0, 'foodCategory': 'canned soup', 'foodId': 'food_a6201h1bu1m0tfbrvis6ma6nvhzv', 'image': 'https://www.edamam.com/food-img/946/946c38a4c278da4361d2615d653d685a.jpg'}], 'totalWeight': 593.8515571134021, 'totalTime': 0.0, 'cuisineType': ['american'], 'mealType': ['breakfast'], 'dishType': ['main course', 'egg'], 'totalNutrients': {'ENERC_KCAL': {'label': 'Energy', 'quantity': 1443.9800000000002, 'unit': 'kcal'}, 'FAT': {'label': 'Fat', 'quantity': 55.1498, 'unit': 'g'}, 'FASAT': {'label': 'Saturated', 'quantity': 13.013679999999999, 'unit': 'g'}, 'FATRN': {'label': 'Trans', 'quantity': 0.18602000000000002, 'unit': 'g'}, 'FAMS': {'label': 'Monounsaturated', 'quantity': 23.72736, 'unit': 'g'}, 'FAPU': {'label': 'Polyunsaturated', 'quantity': 14.43776, 'unit': 'g'}, 'CHOCDF': {'label': 'Carbs', 'quantity': 177.22979999999998, 'unit': 'g'}, 'CHOCDF.net': {'label': 'Carbohydrates (net)', 'quantity': 162.61979999999997, 'unit': 'g'}, 'FIBTG': {'label': 'Fiber', 'quantity': 14.610000000000003, 'unit': 'g'}, 'SUGAR': {'label': 'Sugars', 'quantity': 1.3483999999999998, 'unit': 'g'}, 'PROCNT': {'label': 'Protein', 'quantity': 62.6634, 'unit': 'g'}, 'CHOLE': {'label': 'Cholesterol', 'quantity': 1279.68, 'unit': 'mg'}, 'NA': {'label': 'Sodium', 'quantity': 1376.6841600000002, 'unit': 'mg'}, 'CA': {'label': 'Calcium', 'quantity': 508.2043737072165, 'unit': 'mg'}, 'MG': {'label': 'Magnesium', 'quantity': 253.63851557113406, ...
# 9

# %% [markdown]
# So when setting all these parameters, we tend not to get too many results as multiple parameters could be contradictory and result in not recipes that meet our criteria. So we need to decide on combinations of parameters that are good (will return non-empty lists at least, but preferably lists with a large number of recipes). We could do this manually, but instead we can do this with adaptive sampling.

# %%
from pydantic import BaseModel, Field
import random
import time
from collections import Counter

# %%
class RecipeParameters(BaseModel):
    """Stores all valid parameter values for recipe searches"""
    diet_labels: list[str] = Field(
        description="List of valid diet labels (e.g. 'balanced', 'high-protein', 'low-fat')",
    )
    health_labels: list[str] = Field(
        description="List of valid health labels (e.g. 'egg-free', 'gluten-free', 'peanut-free')",
    )
    meal_types: list[str] = Field(
        description="List of valid meal types (e.g. 'breakfast', 'lunch', 'dinner')",
    )
    dish_types: list[str] = Field(
        description="List of valid dish types (e.g. 'salad', 'main course', 'dessert')",
    )
    cuisine_types: list[str] = Field(
        description="List of valid cuisine types (e.g. 'american', 'italian', 'chinese')",
    )
    
    class Config:
        json_schema_extra = {
            "example": {
                "diet_labels": ["balanced", "high-protein"],
                "health_labels": ["egg-free", "gluten-free"],
                "meal_types": ["breakfast", "lunch"],
                "dish_types": ["salad", "main course"],
                "cuisine_types": ["american", "italian"]
            }
        }

# %%
class ParameterStats(BaseModel):
    """Statistics for parameter success rates"""
    success: int = Field(default=0, description="Number of successful queries")
    total: int = Field(default=0, description="Total number of queries")

# %%
from typing import Any

class RecipeDataCollector:
    def __init__(self,
                 params: RecipeParameters,
                 api_client: Any,
                 min_recipes_per_category: int = 100,
                 max_retries: int = 3,
                 rate_limit: float = 0.5):
        self.params = params
        self.api_client = api_client
        self.min_recipes = min_recipes_per_category
        self.max_retries = max_retries
        self.rate_limit = rate_limit
        self.collected_recipes: dict[str, dict] = {}
        self.parameter_stats: dict[str, ParameterStats] = {}
        
    def _update_stats(self, params: dict[str, list[str]], success: bool):
        """Update success statistics for parameter combinations"""
        for param_type in params:
            if param_type not in self.parameter_stats:
                self.parameter_stats[param_type] = ParameterStats()
                
            stats = self.parameter_stats[param_type]
            stats.total += 1
            if success:
                stats.success += 1
                
    def _store_recipe(self, recipe: dict):
        """Store recipe with additional metadata."""
        recipe_id = recipe['uri']
        self.collected_recipes[recipe_id] = {
            **recipe,
            'collection_timestamp': time.time(),
            'parameter_stats': self.parameter_stats.copy()
        }
    
    def _get_param_success_rate(self, param_type: str) -> float:
        """Calculate success rate for a parameter type"""
        if param_type not in self.parameter_stats:
            return 0.5
        
        stats = self.parameter_stats[param_type]
        return stats.success / stats.total if stats.total > 0 else 0.5
    
    def _generate_parameter_combination(self) -> dict[str, list[str]]:
            """
            Generate a smart parameter combination based on historical success rates.
            
            Returns:
                Dictionary of parameters to use in the next query
            """
            params = {}
            
            # Available parameter types
            param_types = ['diet_labels', 'health_labels', 'meal_types', 
                        'dish_types', 'cuisine_types']
            
            # Start with one random parameter type
            primary_param = random.choice(param_types)
            param_values = getattr(self.params, primary_param)
            params[primary_param] = [random.choice(param_values)]
            
            # Maybe add more parameters based on their success rates
            for param_type in param_types:
                if param_type != primary_param:
                    success_rate = self._get_param_success_rate(param_type)
                    if random.random() < success_rate:
                        param_values = getattr(self.params, param_type)
                        params[param_type] = [random.choice(param_values)]
                        
            return params
        
    async def collect_recipes(self, target_recipes: int = 1000) -> list[dict]:
        """
        Collect recipes using adaptive parameter sampling.
        
        Args:
            target_recipes: Number of unique recipes to collect
            
        Returns:
            List of collected recipes
        """
        unique_recipes = set()
        retries = 0
        
        while len(unique_recipes) < target_recipes and retries < self.max_retries:
            try:
                # Generate parameter combination
                params = self._generate_parameter_combination()
                print(f"Trying parameters: {params}")
                
                # Rate limiting
                time.sleep(self.rate_limit)
                
                # Get recipes
                recipes = await self.api_client.get_recipes(**params)
                
                if recipes:
                    # Update stats for successful combination
                    self._update_stats(params, success=True)
                    
                    # Store new unique recipes
                    for recipe in recipes:
                        recipe_id = recipe['uri']
                        if recipe_id not in unique_recipes:
                            unique_recipes.add(recipe_id)
                            self._store_recipe(recipe)
                else:
                    # Update stats for unsuccessful combination
                    self._update_stats(params, success=False)
                    
                print(f"Collected {len(unique_recipes)} unique recipes")
                
            except Exception as e:
                print(f"Error collecting recipes: {str(e)}")
                retries += 1
                
        return list(self.collected_recipes.values())

# %%
def _get_param_success_rate(self, param_type: str) -> float:
    """Calculate success rate for a parameter type"""
    if param_type not in self.parameter_stats:
        return 0.5
    
    stats = self.parameter_stats[param_type]
    return stats.success / stats.total if stats.total > 0 else 0.5

# %%
params = {}

# Available parameter types
param_types = ['diet_labels', 'health_labels', 'meal_types', 
            'dish_types', 'cuisine_types']

# Start with one random parameter type
primary_param = random.choice(param_types)
param_values = getattr(RecipeParameters, primary_param)
params[primary_param] = [random.choice(param_values)]

# Maybe add more parameters based on their success rates
for param_type in param_types:
    if param_type != primary_param:
        success_rate = _get_param_success_rate(param_type)
        if random.random() < success_rate:
            param_values = getattr(RecipeParameters, param_type)
            params[param_type] = [random.choice(param_values)]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[48], line 9
#       7 # Start with one random parameter type
#       8 primary_param = random.choice(param_types)
# ----> 9 param_values = getattr(RecipeParameters, primary_param)
#      10 params[primary_param] = [random.choice(param_values)]
#      12 # Maybe add more parameters based on their success rates
#
# File ~/envs/iffymate/lib/python3.12/site-packages/pydantic/_internal/_model_construction.py:264, in ModelMetaclass.__getattr__(self, item)
#     262 if private_attributes and item in private_attributes:
#     263     return private_attributes[item]
# --> 264 raise AttributeError(item)
#
# AttributeError: diet_labels

# %%
# First, import everything we need
from pydantic import BaseModel, Field
import asyncio
import aiohttp
import time
import random
from typing import Any

# We already have our RecipeParameters and ParameterStats classes defined

# Let's create a simple API client for Edamam
class EdamamClient:
    def __init__(self, app_id: str, app_key: str):
        self.app_id = app_id
        self.app_key = app_key
        
    async def get_recipes(self, **params) -> list[dict]:
        """Get recipes from Edamam API"""
        base_params = {
            'type': 'public',
            'app_id': self.app_id,
            'app_key': self.app_key,
            'imageSize': 'THUMBNAIL',
            'random': 'true'
        }
        
        # Merge base params with provided params
        params = {**base_params, **params}
        
        async with aiohttp.ClientSession() as session:
            async with session.get('https://api.edamam.com/api/recipes/v2', params=params) as response:
                data = await response.json()
                return [hit['recipe'] for hit in data.get('hits', [])]

# Now let's use it:
async def main():
    # Initialize parameters with our lists from earlier
    params = RecipeParameters(
        diet_labels=diet_labels,
        health_labels=health_labels,
        meal_types=meal_types,
        dish_types=dish_types,
        cuisine_types=cuisine_types
    )

    # Create API client
    api_client = EdamamClient(
        app_id=edamam_api_id,
        app_key=edamam_api_key
    )

    # Create collector
    collector = RecipeDataCollector(
        params=params,
        api_client=api_client,
        min_recipes_per_category=10,  # Start small for testing
        max_retries=3,
        rate_limit=1.0  # 1 second between requests
    )

    # Collect recipes
    recipes = await collector.collect_recipes(target_recipes=100)  # Start with a small number
    
    # Print stats
    print(f"Collected {len(recipes)} recipes")
    print("\nParameter success rates:")
    for param_type, stats in collector.parameter_stats.items():
        success_rate = stats.success / stats.total if stats.total > 0 else 0
        print(f"{param_type}: {success_rate:.2%} ({stats.success}/{stats.total})")

    return recipes

# In Jupyter, run it like this:
recipes = await main()
# Out:
# Trying parameters: {'health_labels': ['mustard-free'], 'diet_labels': ['high-fiber'], 'dish_types': ['egg']}
# Collected 20 unique recipes
# Trying parameters: {'dish_types': ['alcohol cocktail'], 'diet_labels': ['low-carb'], 'health_labels': ['mustard-free'], 'meal_types': ['lunch']}
# Collected 40 unique recipes
# Trying parameters: {'dish_types': ['side dish'], 'diet_labels': ['low-fat'], 'health_labels': ['fodmap-free'], 'meal_types': ['breakfast'], 'cuisine_types': ['central europe']}
# Collected 60 unique recipes
# Trying parameters: {'dish_types': ['pizza'], 'diet_labels': ['high-fiber'], 'health_labels': ['low-potassium'], 'meal_types': ['brunch'], 'cuisine_types': ['japanese']}
# Collected 80 unique recipes
# Trying parameters: {'dish_types': ['biscuits and cookies'], 'diet_labels': ['low-carb'], 'health_labels': ['DASH'], 'meal_types': ['lunch'], 'cuisine_types': ['world']}
# Collected 100 unique recipes
# Collected 100 recipes
#
# Parameter success rates:
# health_labels: 100.00% (5/5)
# diet_labels: 100.00% (5/5)
# dish_types: 100.00% (5/5)
# meal_types: 100.00% (4/4)
# cuisine_types: 100.00% (3/3)

# %%
api_client = EdamamClient(
    app_id=edamam_api_id,
    app_key=edamam_api_key
)

params = RecipeParameters(
    diet_labels=diet_labels,
    health_labels=health_labels,
    meal_types=meal_types,
    dish_types=dish_types,
    cuisine_types=cuisine_types
)

collector = RecipeDataCollector(
    params=params,
    api_client=api_client,
    min_recipes_per_category=10,  # Start small for testing
    max_retries=3,
    rate_limit=1.0  # 1 second between requests
)

# %%
if recipes:
    first_recipe = recipes[0]
    print("\nExample recipe:")
    print(f"Name: {first_recipe['label']}")
    print(f"Cuisine: {first_recipe.get('cuisineType', 'Not specified')}")
    print(f"Meal Type: {first_recipe.get('mealType', 'Not specified')}")
    print(f"Diet Labels: {first_recipe.get('dietLabels', 'None')}")
# Out:
# Example recipe:
# Name: Mom’s Swedish Potatoes recipes
# Cuisine: ['nordic']
# Meal Type: ['lunch/dinner']
# Diet Labels: []

# %%
for recipe in recipes:
    print(f"\nRecipe: {recipe['label']}")
    print("Parameters used:")
    print(f"- Cuisine: {recipe.get('cuisineType', 'Not specified')}")
    print(f"- Diet Labels: {recipe.get('dietLabels', 'None')}")
    print(f"- Health Labels: {recipe.get('healthLabels', 'None')}")
    print(f"- Meal Type: {recipe.get('mealType', 'Not specified')}")
    print(f"- Dish Type: {recipe.get('dishType', 'Not specified')}")
# Out:
# Recipe: Mom’s Swedish Potatoes recipes
# Parameters used:
# - Cuisine: ['nordic']
# - Diet Labels: []
# - Health Labels: ['Sugar-Conscious', 'Vegetarian', 'Pescatarian', 'Egg-Free', 'Peanut-Free', 'Tree-Nut-Free', 'Soy-Free', 'Fish-Free', 'Shellfish-Free', 'Pork-Free', 'Red-Meat-Free', 'Crustacean-Free', 'Celery-Free', 'Mustard-Free', 'Sesame-Free', 'Lupine-Free', 'Mollusk-Free', 'Alcohol-Free', 'Sulfite-Free', 'Kosher', 'Immuno-Supportive']
# - Meal Type: ['lunch/dinner']
# - Dish Type: ['condiments and sauces']
#
# Recipe: Soft Chocolate Chip Cookies
# Parameters used:
# - Cuisine: ['american']
# - Diet Labels: ['Low-Sodium']
# - Health Labels: ['Low Potassium', 'Kidney-Friendly', 'Vegetarian', 'Pescatarian', 'Peanut-Free', 'Soy-Free', 'Fish-Free', 'Shellfish-Free', 'Pork-Free', 'Red-Meat-Free', 'Crustacean-Free', 'Celery-Free', 'Mustard-Free', 'Sesame-Free', 'Lupine-Free', 'Mollusk-Free', 'Alcohol-Free', 'Kosher']
# - Meal Type: ['teatime']
# - Dish Type: ['biscuits and cookies']
#
# Recipe: Zucchini Bread with Lemon Honey Butter
# Parameters used:
# - Cuisine: ['american']
# - Diet Labels: []
# - Health Labels: ['Low Potassium', 'Kidney-Friendly', 'Vegetarian', 'Pescatarian', 'Peanut-Free', 'Tree-Nut-Free', 'Soy-Free', 'Fish-Free', 'Shellfish-Free', 'Pork-Free', 'Red-Meat-Free', 'Crustacean-Free', 'Celery-Free', 'Mustard-Free', 'Sesame-Free', 'Lupine-Free', 'Mollusk-Free', 'Alcohol-Free', 'Kosher']
# - Meal Type: ['lunch/dinner']
# - Dish Type: ['bread']
#
# Recipe: Crispy Zucchini Sticks with Spicy Marinara Dipping Sauce recipes
# Parameters used:
# - Cuisine: ['italian']
# - Diet Labels: ['High-Fiber']
# - Health Labels: ['Vegetarian', 'Pescatarian', 'Peanut-Free', 'Tree-Nut-Free', 'Soy-Free', 'Fish-Free', 'Shellfish-Free', 'Pork-Free', 'Red-Meat-Free', 'Crustacean-Free', 'Celery-Free', 'Mustard-Free', 'Sesame-Free', 'Lupine-Free', 'Mollusk-Free', 'Alcohol-Free', 'Sulfite-Free', 'Kosher']
# - Meal Type: ['lunch/dinner']
# - Dish Type: ['condiments and sauces']
#
# Recipe: Deviled Egg Spread
# Parameters used:
# - Cuisine: ['american']
# - Diet Labels: ['Low-Carb']
# - Health Labels: ['Sugar-Conscious', 'Low Potassium', 'Keto-Friendly', 'Vegetarian', 'Pescatarian', 'Paleo', 'Dairy-Free', 'Gluten-Free', 'Wheat-Free', 'Peanut-Free', 'Tree-Nut-Free', 'Soy-Free', 'Fish-Free', 'Shellfish-Free', 'Pork-Free', 'Red-Meat-Free', 'Crustacean-Free', 'Sesame-Free', 'Lupine-Free', 'Mollusk-Free', 'Alcohol-Free', 'Sulfite-Free', 'Kosher']
# - Meal Type: ['lunch/dinner']
# - Dish Type: ['starter']
#
# Recipe: Cider-cooked Apple, Onion And Cheese Galette recipes
# Parameters used:
# - Cuisine: ['french']
# - Diet Labels: []
# - Health Labels: ['Vegetarian', 'Pescatarian', 'Peanut-Free', 'Tree-Nut-Free', 'Soy-Free', 'Fish-Free', 'Shellfish-Free', 'Pork-Free', 'Red-Meat-Free', 'Crustacean-Free', 'Celery-Free', 'Sesame-Free', 'Lupine-Free', 'Mollusk-Free', 'Alcohol-Free', 'Sulfite-Free', 'Kosher']
# - Meal Type: ['lunch/dinner']
# - Dish Type: ['desserts']
#
# Recipe: Tart Summer Pork Stew with Tomatoes and To
# Parameters used:
# - Cuisine: ['french']
# - Diet Labels: []
# - Health Labels: ['Dairy-Free', 'Peanut-Free', 'Tree-Nut-Free', 'Soy-Free', 'Fish-Free', 'Shellfish-Free', 'Crustacean-Free', 'Celery-Free', 'Mustard-Free', 'Sesame-Free', 'Lupine-Free', 'Mollusk-Free']
# - Meal Type: ['lunch/dinner']
# - Dish Type: ['main course']
#
# Recipe: Turkey Monte Cristo recipes
# Parameters used:
# - Cuisine: ['american']
# - Diet Labels: []
# - Health Labels: ['Kidney-Friendly', 'Peanut-Free', 'Tree-Nut-Free', 'Soy-Free', 'Fish-Free', 'Shellfish-Free', 'Pork-Free', 'Red-Meat-Free', 'Crustacean-Free', 'Celery-Free', 'Sesame-Free', 'Lupine-Free', 'Mollusk-Free', 'Alcohol-Free', 'Sulfite-Free']
# - Meal Type: ['breakfast']
# - Dish Type: ['desserts']
#
# Recipe: Simple Minestrone Soup with Tortellini
# Parameters used:
# - Cuisine: ['italian']
# - Diet Labels: ['High-Fiber']
# - Health Labels: ['Egg-Free', 'Peanut-Free', 'Tree-Nut-Free', 'Fish-Free', 'Shellfish-Free', 'Pork-Free', 'Crustacean-Free', 'Mustard-Free', 'Sesame-Free', 'Lupine-Free', 'Mollusk-Free', 'Alcohol-Free', 'Sulfite-Free']
# - Meal Type: ['lunch/dinner']
# - Dish Type: ['soup', 'main course']
#
# Recipe: Honey Spice Chicken Thighs
# Parameters used:
# - Cuisine: ['mediterranean']
# - Diet Labels: ['Low-Carb']
# - Health Labels: ['Paleo', 'Dairy-Free', 'Gluten-Free', 'Wheat-Free', 'Egg-Free', 'Peanut-Free', 'Tree-Nut-Free', 'Soy-Free', 'Fish-Free', 'Shellfish-Free', 'Pork-Free', 'Red-Meat-Free', 'Crustacean-Free', 'Celery-Free', 'Mustard-Free', 'Sesame-Free', 'Lupine-Free', 'Mollusk-Free', 'Alcohol-Free', 'No oil added', 'Kosher']
# - Meal Type: ['lunch/dinner']
# - Dish Type: ['condiments and sauces']
#
# Recipe: Poulet a la Regina
# Parameters used:
# - Cuisine: ['french']
# - Diet Labels: []
# - Health Labels: ['Sugar-Conscious', 'Gluten-Free', 'Wheat-Free', 'Egg-Free', 'Peanut-Free', 'Tree-Nut-Free', 'Soy-Free', 'Fish-Free', 'Shellfish-Free', 'Pork-Free', 'Red-Meat-Free', 'Crustacean-Free', 'Celery-Free', 'Mustard-Free', 'Sesame-Free', 'Lupine-Free', 'Mollusk-Free']
# - Meal Type: ['lunch/dinner']
# - Dish Type: ['starter']
#
# Recipe: Chicken coconut noodles
# Parameters used:
# - Cuisine: ['asian']
# - Diet Labels: ['Balanced', 'High-Fiber']
# - Health Labels: ['Dairy-Free', 'Peanut-Free', 'Tree-Nut-Free', 'Shellfish-Free', 'Pork-Free', 'Red-Meat-Free', 'Celery-Free', 'Mustard-Free', 'Lupine-Free', 'Alcohol-Free', 'Kosher']
# - Meal Type: ['lunch/dinner']
# - Dish Type: ['main course']
#
# Recipe: Chinese duck and vegetable crepes
# Parameters used:
# - Cuisine: ['chinese']
# - Diet Labels: ['Low-Carb', 'Low-Sodium']
# - Health Labels: ['Sugar-Conscious', 'Kidney-Friendly', 'Keto-Friendly', 'Tree-Nut-Free', 'Fish-Free', 'Pork-Free', 'Crustacean-Free', 'Celery-Free', 'Mustard-Free', 'Sesame-Free', 'Lupine-Free', 'Alcohol-Free', 'Sulfite-Free']
# - Meal Type: ['lunch/dinner']
# - Dish Type: ['pancake']
#
# Recipe: Raspberry Cake Topped with Fruit
# Parameters used:
# - Cuisine: ['american']
# - Diet Labels: []
# - Health Labels: ['Kidney-Friendly', 'Peanut-Free', 'Tree-Nut-Free', 'Soy-Free', 'Fish-Free', 'Shellfish-Free', 'Red-Meat-Free', 'Crustacean-Free', 'Celery-Free', 'Mustard-Free', 'Sesame-Free', 'Lupine-Free', 'Mollusk-Free', 'Alcohol-Free']
# - Meal Type: ['lunch/dinner']
# - Dish Type: ['desserts']
#
# Recipe: Herbed Slow Cooker Chicken
# Parameters used:
# - Cuisine: ['american']
# - Diet Labels: ['Low-Carb', 'Low-Sodium']
# - Health Labels: ['Sugar-Conscious', 'Low Potassium', 'Kidney-Friendly', 'Keto-Friendly', 'Paleo', 'Mediterranean', 'Dairy-Free', 'Gluten-Free', 'Wheat-Free', 'Egg-Free', 'Peanut-Free', 'Tree-Nut-Free', 'Soy-Free', 'Fish-Free', 'Shellfish-Free', 'Pork-Free', 'Red-Meat-Free', 'Crustacean-Free', 'Celery-Free', 'Mustard-Free', 'Sesame-Free', 'Lupine-Free', 'Mollusk-Free', 'Alcohol-Free', 'Sulfite-Free', 'Kosher']
# - Meal Type: ['lunch/dinner']
# - Dish Type: ['main course']
#
# Recipe: Bourbon BBQ Sauce, Perfect for Summer Grilling
# Parameters used:
# - Cuisine: ['world']
# - Diet Labels: []
# - Health Labels: ['Vegan', 'Vegetarian', 'Pescatarian', 'Dairy-Free', 'Gluten-Free', 'Wheat-Free', 'Egg-Free', 'Peanut-Free', 'Tree-Nut-Free', 'Fish-Free', 'Shellfish-Free', 'Pork-Free', 'Red-Meat-Free', 'Crustacean-Free', 'Celery-Free', 'Mustard-Free', 'Sesame-Free', 'Lupine-Free', 'Mollusk-Free', 'Kosher', 'Alcohol-Cocktail']
# - Meal Type: ['lunch/dinner']
# - Dish Type: ['alcohol cocktail']
#
# Recipe: Vietnamese Crispy Fish with Cilantro recipes
# Parameters used:
# - Cuisine: ['south east asian']
# - Diet Labels: ['High-Protein', 'Low-Carb']
# - Health Labels: ['Pescatarian', 'Dairy-Free', 'Gluten-Free', 'Wheat-Free', 'Egg-Free', 'Tree-Nut-Free', 'Soy-Free', 'Shellfish-Free', 'Pork-Free', 'Red-Meat-Free', 'Celery-Free', 'Mustard-Free', 'Sesame-Free', 'Lupine-Free', 'Alcohol-Free', 'Kosher']
# - Meal Type: ['lunch/dinner']
# - Dish Type: ['condiments and sauces']
#
# Recipe: Easy Cheesy Fondue #Ragu
# Parameters used:
# - Cuisine: ['italian']
# - Diet Labels: ['Balanced', 'High-Fiber']
# - Health Labels: ['Egg-Free', 'Peanut-Free', 'Tree-Nut-Free', 'Fish-Free', 'Shellfish-Free', 'Crustacean-Free', 'Celery-Free', 'Mustard-Free', 'Sesame-Free', 'Lupine-Free', 'Mollusk-Free', 'Alcohol-Free', 'Sulfite-Free']
# - Meal Type: ['lunch/dinner']
# - Dish Type: ['main course']
#
# Recipe: Cornbread & Oyster-Mushroom Stuffing
# Parameters used:
# - Cuisine: ['american']
# - Diet Labels: ['Low-Sodium']
# - Health Labels: ['Low Potassium', 'Kidney-Friendly', 'Vegetarian', 'Pescatarian', 'Peanut-Free', 'Tree-Nut-Free', 'Soy-Free', 'Fish-Free', 'Shellfish-Free', 'Pork-Free', 'Red-Meat-Free', 'Crustacean-Free', 'Celery-Free', 'Mustard-Free', 'Sesame-Free', 'Lupine-Free', 'Mollusk-Free', 'Alcohol-Free', 'Kosher']
# - Meal Type: ['lunch/dinner']
# - Dish Type: ['starter']
#
# Recipe: Mango Popsicle
# Parameters used:
# - Cuisine: ['american']
# - Diet Labels: ['Low-Fat', 'Low-Sodium']
# - Health Labels: ['Kidney-Friendly', 'Vegetarian', 'Pescatarian', 'Gluten-Free', 'Wheat-Free', 'Egg-Free', 'Peanut-Free', 'Tree-Nut-Free', 'Soy-Free', 'Fish-Free', 'Shellfish-Free', 'Pork-Free', 'Red-Meat-Free', 'Crustacean-Free', 'Celery-Free', 'Mustard-Free', 'Sesame-Free', 'Lupine-Free', 'Mollusk-Free', 'Alcohol-Free', 'No oil added', 'Kosher']
# - Meal Type: ['lunch/dinner']
# - Dish Type: ['desserts']
#
# Recipe: Pepperoni Breadstick Bites
# Parameters used:
# - Cuisine: ['italian']
# - Diet Labels: ['Balanced']
# - Health Labels: ['Sugar-Conscious', 'Low Potassium', 'Dairy-Free', 'Egg-Free', 'Peanut-Free', 'Tree-Nut-Free', 'Soy-Free', 'Fish-Free', 'Shellfish-Free', 'Crustacean-Free', 'Celery-Free', 'Mustard-Free', 'Sesame-Free', 'Lupine-Free', 'Mollusk-Free', 'Alcohol-Free', 'Sulfite-Free']
# - Meal Type: ['brunch']
# - Dish Type: ['bread']
#
# Recipe: Taco Muffins
# Parameters used:
# - Cuisine: ['mexican']
# - Diet Labels: []
# - Health Labels: ['Sugar-Conscious', 'Kidney-Friendly', 'Egg-Free', 'Peanut-Free', 'Tree-Nut-Free', 'Soy-Free', 'Fish-Free', 'Shellfish-Free', 'Pork-Free', 'Crustacean-Free', 'Celery-Free', 'Mustard-Free', 'Sesame-Free', 'Lupine-Free', 'Mollusk-Free', 'Alcohol-Free', 'Sulfite-Free']
# - Meal Type: ['brunch']
# - Dish Type: ['desserts']
#
# Recipe: GLUTEN-FREE PEANUT BUTTER & CHOCOLATE TURTLE POKE CAKE recipes
# Parameters used:
# - Cuisine: ['american']
# - Diet Labels: []
# - Health Labels: ['Vegetarian', 'Pescatarian', 'Soy-Free', 'Fish-Free', 'Shellfish-Free', 'Pork-Free', 'Red-Meat-Free', 'Crustacean-Free', 'Celery-Free', 'Mustard-Free', 'Sesame-Free', 'Lupine-Free', 'Mollusk-Free', 'Alcohol-Free', 'Kosher']
# - Meal Type: ['lunch/dinner']
# - Dish Type: ['desserts']
#
# Recipe: Deconstructed Larabars
# Parameters used:
# - Cuisine: ['american']
# - Diet Labels: ['Low-Sodium']
# - Health Labels: ['Kidney-Friendly', 'Vegetarian', 'Pescatarian', 'Gluten-Free', 'Wheat-Free', 'Egg-Free', 'Soy-Free', 'Fish-Free', 'Shellfish-Free', 'Pork-Free', 'Red-Meat-Free', 'Crustacean-Free', 'Celery-Free', 'Mustard-Free', 'Sesame-Free', 'Lupine-Free', 'Mollusk-Free', 'Alcohol-Free', 'Sulfite-Free', 'Kosher', 'Immuno-Supportive']
# - Meal Type: ['breakfast']
# - Dish Type: ['condiments and sauces']
#
# Recipe: Chai Panna Cotta recipes
# Parameters used:
# - Cuisine: ['italian']
# - Diet Labels: ['Low-Sodium']
# - Health Labels: ['Low Potassium', 'Kidney-Friendly', 'Gluten-Free', 'Wheat-Free', 'Egg-Free', 'Peanut-Free', 'Tree-Nut-Free', 'Soy-Free', 'Fish-Free', 'Shellfish-Free', 'Red-Meat-Free', 'Crustacean-Free', 'Celery-Free', 'Mustard-Free', 'Sesame-Free', 'Lupine-Free', 'Mollusk-Free', 'Alcohol-Free', 'No oil added']
# - Meal Type: ['lunch/dinner']
# - Dish Type: ['desserts']
#
# Recipe: Cherry And Plum Crumbles With Goat Cheese Ice Cream
# Parameters used:
# - Cuisine: ['american']
# - Diet Labels: []
# - Health Labels: ['Vegetarian', 'Pescatarian', 'Gluten-Free', 'Wheat-Free', 'Peanut-Free', 'Tree-Nut-Free', 'Soy-Free', 'Fish-Free', 'Shellfish-Free', 'Pork-Free', 'Red-Meat-Free', 'Crustacean-Free', 'Celery-Free', 'Mustard-Free', 'Sesame-Free', 'Lupine-Free', 'Mollusk-Free', 'Alcohol-Free', 'Kosher']
# - Meal Type: ['lunch/dinner']
# - Dish Type: ['desserts']
#
# Recipe: Chicken Penne Bake
# Parameters used:
# - Cuisine: ['italian']
# - Diet Labels: []
# - Health Labels: ['Sugar-Conscious', 'Mediterranean', 'Egg-Free', 'Peanut-Free', 'Tree-Nut-Free', 'Soy-Free', 'Fish-Free', 'Shellfish-Free', 'Pork-Free', 'Red-Meat-Free', 'Crustacean-Free', 'Celery-Free', 'Mustard-Free', 'Sesame-Free', 'Lupine-Free', 'Mollusk-Free', 'Alcohol-Free', 'No oil added', 'Sulfite-Free']
# - Meal Type: ['lunch/dinner']
# - Dish Type: ['main course']
#
# Recipe: Spicy Avocado Dressing
# Parameters used:
# - Cuisine: ['mexican']
# - Diet Labels: ['High-Fiber', 'Low-Carb']
# - Health Labels: ['Sugar-Conscious', 'Keto-Friendly', 'Vegetarian', 'Pescatarian', 'Mediterranean', 'Gluten-Free', 'Wheat-Free', 'Egg-Free', 'Peanut-Free', 'Tree-Nut-Free', 'Soy-Free', 'Fish-Free', 'Shellfish-Free', 'Pork-Free', 'Red-Meat-Free', 'Crustacean-Free', 'Celery-Free', 'Mustard-Free', 'Sesame-Free', 'Lupine-Free', 'Mollusk-Free', 'Alcohol-Free', 'No oil added', 'Sulfite-Free', 'Kosher', 'Immuno-Supportive']
# - Meal Type: ['snack']
# - Dish Type: ['condiments and sauces']
#
# Recipe: Brown Derby
# Parameters used:
# - Cuisine: ['world']
# - Diet Labels: ['Low-Fat', 'Low-Sodium']
# - Health Labels: ['Low Potassium', 'Kidney-Friendly', 'Vegetarian', 'Pescatarian', 'Paleo', 'Dairy-Free', 'Gluten-Free', 'Wheat-Free', 'Egg-Free', 'Peanut-Free', 'Tree-Nut-Free', 'Soy-Free', 'Fish-Free', 'Shellfish-Free', 'Pork-Free', 'Red-Meat-Free', 'Crustacean-Free', 'Celery-Free', 'Mustard-Free', 'Sesame-Free', 'Lupine-Free', 'Mollusk-Free', 'No oil added', 'Kosher', 'Alcohol-Cocktail']
# - Meal Type: ['lunch/dinner']
# - Dish Type: ['alcohol cocktail']
#
# Recipe: Eggplant Tacos
# Parameters used:
# - Cuisine: ['mexican']
# - Diet Labels: []
# - Health Labels: ['Vegetarian', 'Pescatarian', 'Mediterranean', 'Egg-Free', 'Peanut-Free', 'Tree-Nut-Free', 'Soy-Free', 'Fish-Free', 'Shellfish-Free', 'Pork-Free', 'Red-Meat-Free', 'Crustacean-Free', 'Celery-Free', 'Mustard-Free', 'Sesame-Free', 'Lupine-Free', 'Mollusk-Free', 'Alcohol-Free', 'Sulfite-Free', 'Kosher']
# - Meal Type: ['lunch/dinner']
# - Dish Type: ['sandwiches']
#
# Recipe: Canning Green Beans for Food Storage
# Parameters used:
# - Cuisine: ['mediterranean']
# - Diet Labels: ['High-Fiber', 'Low-Fat']
# - Health Labels: ['Vegan', 'Vegetarian', 'Pescatarian', 'Mediterranean', 'DASH', 'Dairy-Free', 'Gluten-Free', 'Wheat-Free', 'Egg-Free', 'Peanut-Free', 'Tree-Nut-Free', 'Soy-Free', 'Fish-Free', 'Shellfish-Free', 'Pork-Free', 'Red-Meat-Free', 'Crustacean-Free', 'Celery-Free', 'Mustard-Free', 'Sesame-Free', 'Lupine-Free', 'Mollusk-Free', 'Alcohol-Free', 'No oil added', 'Sulfite-Free', 'Kosher', 'Immuno-Supportive']
# - Meal Type: ['lunch/dinner']
# - Dish Type: ['main course']
#
# Recipe: Chicken Muffuletta Recipe
# Parameters used:
# - Cuisine: ['italian']
# - Diet Labels: ['Low-Carb']
# - Health Labels: ['Sugar-Conscious', 'Low Potassium', 'Kidney-Friendly', 'Egg-Free', 'Peanut-Free', 'Tree-Nut-Free', 'Soy-Free', 'Fish-Free', 'Shellfish-Free', 'Crustacean-Free', 'Celery-Free', 'Mustard-Free', 'Sesame-Free', 'Lupine-Free', 'Mollusk-Free', 'Alcohol-Free', 'Sulfite-Free']
# - Meal Type: ['lunch/dinner']
# - Dish Type: ['main course']
#
# Recipe: Spritz Cookies Recipe, Cookie Press Recipe, Butter Cookies
# Parameters used:
# - Cuisine: ['american']
# - Diet Labels: ['Low-Sodium']
# - Health Labels: ['Low Potassium', 'Kidney-Friendly', 'Vegetarian', 'Pescatarian', 'Peanut-Free', 'Tree-Nut-Free', 'Soy-Free', 'Fish-Free', 'Shellfish-Free', 'Pork-Free', 'Red-Meat-Free', 'Crustacean-Free', 'Celery-Free', 'Mustard-Free', 'Sesame-Free', 'Lupine-Free', 'Mollusk-Free', 'Alcohol-Free', 'Kosher']
# - Meal Type: ['teatime']
# - Dish Type: ['biscuits and cookies']
#
# Recipe: Classic Nacho Cheese Dip recipes
# Parameters used:
# - Cuisine: ['mexican']
# - Diet Labels: ['Low-Carb']
# - Health Labels: ['Vegetarian', 'Pescatarian', 'Egg-Free', 'Peanut-Free', 'Tree-Nut-Free', 'Soy-Free', 'Fish-Free', 'Shellfish-Free', 'Pork-Free', 'Red-Meat-Free', 'Crustacean-Free', 'Celery-Free', 'Mustard-Free', 'Sesame-Free', 'Lupine-Free', 'Mollusk-Free', 'Alcohol-Free', 'Sulfite-Free', 'Kosher']
# - Meal Type: ['lunch/dinner']
# - Dish Type: ['condiments and sauces']
#
# Recipe: Creamy Bacon Guacamole Potato Bites recipes
# Parameters used:
# - Cuisine: ['american']
# - Diet Labels: ['High-Fiber']
# - Health Labels: ['Gluten-Free', 'Wheat-Free', 'Egg-Free', 'Peanut-Free', 'Tree-Nut-Free', 'Soy-Free', 'Fish-Free', 'Shellfish-Free', 'Crustacean-Free', 'Celery-Free', 'Mustard-Free', 'Sesame-Free', 'Lupine-Free', 'Mollusk-Free', 'Alcohol-Free', 'Sulfite-Free']
# - Meal Type: ['lunch/dinner']
# - Dish Type: ['starter']
#
# Recipe: Fresh Tomato Dressing
# Parameters used:
# - Cuisine: ['italian']
# - Diet Labels: ['Balanced']
# - Health Labels: ['Vegan', 'Vegetarian', 'Pescatarian', 'Paleo', 'Mediterranean', 'DASH', 'Dairy-Free', 'Gluten-Free', 'Wheat-Free', 'Egg-Free', 'Peanut-Free', 'Tree-Nut-Free', 'Soy-Free', 'Fish-Free', 'Shellfish-Free', 'Pork-Free', 'Red-Meat-Free', 'Crustacean-Free', 'Celery-Free', 'Mustard-Free', 'Sesame-Free', 'Lupine-Free', 'Mollusk-Free', 'Alcohol-Free', 'Sulfite-Free', 'Kosher', 'Immuno-Supportive']
# - Meal Type: ['lunch/dinner']
# - Dish Type: ['condiments and sauces']
#
# Recipe: Greek Dilled Peas, Potatoes & Carrots
# Parameters used:
# - Cuisine: ['mediterranean']
# - Diet Labels: ['High-Fiber']
# - Health Labels: ['Vegan', 'Vegetarian', 'Pescatarian', 'Mediterranean', 'Dairy-Free', 'Gluten-Free', 'Wheat-Free', 'Egg-Free', 'Peanut-Free', 'Tree-Nut-Free', 'Soy-Free', 'Fish-Free', 'Shellfish-Free', 'Pork-Free', 'Red-Meat-Free', 'Crustacean-Free', 'Celery-Free', 'Mustard-Free', 'Sesame-Free', 'Lupine-Free', 'Mollusk-Free', 'Alcohol-Free', 'Sulfite-Free', 'Kosher']
# - Meal Type: ['lunch/dinner']
# - Dish Type: Not specified
#
# Recipe: {Dried Fruit Biscotti}
# Parameters used:
# - Cuisine: ['italian']
# - Diet Labels: ['Low-Sodium']
# - Health Labels: ['Kidney-Friendly', 'Vegetarian', 'Pescatarian', 'Peanut-Free', 'Soy-Free', 'Fish-Free', 'Shellfish-Free', 'Pork-Free', 'Red-Meat-Free', 'Crustacean-Free', 'Celery-Free', 'Mustard-Free', 'Sesame-Free', 'Lupine-Free', 'Mollusk-Free', 'Alcohol-Free', 'Kosher']
# - Meal Type: ['lunch/dinner']
# - Dish Type: ['biscuits and cookies']
#
# Recipe: Banana Ice Box Cake
# Parameters used:
# - Cuisine: ['british']
# - Diet Labels: []
# - Health Labels: ['Vegetarian', 'Pescatarian', 'Mediterranean', 'Peanut-Free', 'Tree-Nut-Free', 'Soy-Free', 'Fish-Free', 'Shellfish-Free', 'Pork-Free', 'Red-Meat-Free', 'Crustacean-Free', 'Celery-Free', 'Mustard-Free', 'Sesame-Free', 'Lupine-Free', 'Mollusk-Free', 'Alcohol-Free', 'Sulfite-Free', 'Kosher']
# - Meal Type: ['lunch/dinner']
# - Dish Type: ['desserts']
#
# Recipe: Kalyn's Chipotle Ranch Dressing
# Parameters used:
# - Cuisine: ['mexican']
# - Diet Labels: ['Low-Carb']
# - Health Labels: ['Sugar-Conscious', 'Low Potassium', 'Keto-Friendly', 'Vegetarian', 'Pescatarian', 'Gluten-Free', 'Wheat-Free', 'Egg-Free', 'Peanut-Free', 'Tree-Nut-Free', 'Soy-Free', 'Fish-Free', 'Shellfish-Free', 'Pork-Free', 'Red-Meat-Free', 'Crustacean-Free', 'Celery-Free', 'Mustard-Free', 'Sesame-Free', 'Lupine-Free', 'Mollusk-Free', 'Alcohol-Free', 'Sulfite-Free', 'Kosher']
# - Meal Type: ['lunch/dinner']
# - Dish Type: ['condiments and sauces']
#
# Recipe: Sugar Cookie Bars
# Parameters used:
# - Cuisine: ['american']
# - Diet Labels: []
# - Health Labels: ['Low Potassium', 'Kidney-Friendly', 'Vegetarian', 'Pescatarian', 'Peanut-Free', 'Tree-Nut-Free', 'Soy-Free', 'Fish-Free', 'Shellfish-Free', 'Pork-Free', 'Red-Meat-Free', 'Crustacean-Free', 'Celery-Free', 'Mustard-Free', 'Sesame-Free', 'Lupine-Free', 'Mollusk-Free', 'Alcohol-Free', 'Kosher']
# - Meal Type: ['teatime']
# - Dish Type: ['desserts']
#
# Recipe: Tasty Tuesday
# Parameters used:
# - Cuisine: ['american']
# - Diet Labels: ['Low-Fat', 'Low-Sodium']
# - Health Labels: ['Vegan', 'Vegetarian', 'Pescatarian', 'Dairy-Free', 'Gluten-Free', 'Wheat-Free', 'Egg-Free', 'Peanut-Free', 'Tree-Nut-Free', 'Soy-Free', 'Fish-Free', 'Shellfish-Free', 'Pork-Free', 'Red-Meat-Free', 'Crustacean-Free', 'Mustard-Free', 'Sesame-Free', 'Lupine-Free', 'Mollusk-Free', 'Alcohol-Free', 'No oil added', 'Kosher']
# - Meal Type: ['teatime']
# - Dish Type: ['drinks']
#
# Recipe: Lasagna Dip
# Parameters used:
# - Cuisine: ['italian']
# - Diet Labels: ['Low-Carb']
# - Health Labels: ['Sugar-Conscious', 'Kidney-Friendly', 'Keto-Friendly', 'Egg-Free', 'Peanut-Free', 'Tree-Nut-Free', 'Soy-Free', 'Fish-Free', 'Shellfish-Free', 'Pork-Free', 'Crustacean-Free', 'Celery-Free', 'Mustard-Free', 'Sesame-Free', 'Lupine-Free', 'Mollusk-Free', 'Alcohol-Free', 'Sulfite-Free']
# - Meal Type: ['lunch/dinner']
# - Dish Type: ['main course']
#
# Recipe: Pumpkin Chocolate Chip Cookies (soft-baked) recipes
# Parameters used:
# - Cuisine: ['american']
# - Diet Labels: ['Low-Sodium']
# - Health Labels: ['Kidney-Friendly']
# - Meal Type: ['teatime']
# - Dish Type: ['biscuits and cookies']
#
# Recipe: Peanut Butter Choco Chip Cookies
# Parameters used:
# - Cuisine: ['american']
# - Diet Labels: ['Low-Sodium']
# - Health Labels: ['Vegetarian', 'Pescatarian', 'Dairy-Free', 'Gluten-Free', 'Wheat-Free', 'Soy-Free', 'Fish-Free', 'Shellfish-Free', 'Pork-Free', 'Red-Meat-Free', 'Crustacean-Free', 'Celery-Free', 'Mustard-Free', 'Sesame-Free', 'Lupine-Free', 'Mollusk-Free', 'Alcohol-Free', 'Kosher']
# - Meal Type: ['teatime']
# - Dish Type: ['biscuits and cookies']
#
# Recipe: Chocolate and Vanilla Swirl Pudding
# Parameters used:
# - Cuisine: ['british']
# - Diet Labels: ['Balanced', 'Low-Sodium']
# - Health Labels: ['Kidney-Friendly', 'Vegetarian', 'Pescatarian', 'Gluten-Free', 'Wheat-Free', 'Peanut-Free', 'Tree-Nut-Free', 'Soy-Free', 'Fish-Free', 'Shellfish-Free', 'Pork-Free', 'Red-Meat-Free', 'Crustacean-Free', 'Celery-Free', 'Mustard-Free', 'Sesame-Free', 'Lupine-Free', 'Mollusk-Free', 'Alcohol-Free', 'Kosher']
# - Meal Type: ['lunch/dinner']
# - Dish Type: ['desserts']
#
# Recipe: Eggs Italiano
# Parameters used:
# - Cuisine: ['american']
# - Diet Labels: ['High-Fiber']
# - Health Labels: ['Vegetarian', 'Pescatarian', 'Mediterranean', 'Peanut-Free', 'Tree-Nut-Free', 'Soy-Free', 'Fish-Free', 'Shellfish-Free', 'Pork-Free', 'Red-Meat-Free', 'Crustacean-Free', 'Celery-Free', 'Mustard-Free', 'Sesame-Free', 'Lupine-Free', 'Mollusk-Free', 'Alcohol-Free', 'Sulfite-Free', 'Kosher']
# - Meal Type: ['breakfast']
# - Dish Type: ['main course']
#
# Recipe: Chef Yucca Chips With Banana Ketchup
# Parameters used:
# - Cuisine: ['south american']
# - Diet Labels: []
# - Health Labels: ['Vegetarian', 'Pescatarian', 'Dairy-Free', 'Egg-Free', 'Peanut-Free', 'Tree-Nut-Free', 'Fish-Free', 'Shellfish-Free', 'Pork-Free', 'Red-Meat-Free', 'Crustacean-Free', 'Celery-Free', 'Mustard-Free', 'Sesame-Free', 'Lupine-Free', 'Mollusk-Free', 'Kosher']
# - Meal Type: ['lunch/dinner']
# - Dish Type: ['starter']
#
# Recipe: Three-Pepper Feta Roll-Ups
# Parameters used:
# - Cuisine: ['mediterranean', 'greek']
# - Diet Labels: ['Balanced']
# - Health Labels: ['Vegetarian', 'Pescatarian', 'Mediterranean', 'Egg-Free', 'Peanut-Free', 'Tree-Nut-Free', 'Soy-Free', 'Fish-Free', 'Shellfish-Free', 'Pork-Free', 'Red-Meat-Free', 'Crustacean-Free', 'Celery-Free', 'Mustard-Free', 'Sesame-Free', 'Lupine-Free', 'Mollusk-Free', 'Alcohol-Free', 'Sulfite-Free', 'Kosher']
# - Meal Type: ['lunch/dinner']
# - Dish Type: ['bread']
#
# Recipe: Citrus Muffins
# Parameters used:
# - Cuisine: ['british']
# - Diet Labels: []
# - Health Labels: ['Kidney-Friendly', 'Vegetarian', 'Pescatarian', 'Egg-Free', 'Peanut-Free', 'Tree-Nut-Free', 'Soy-Free', 'Fish-Free', 'Shellfish-Free', 'Pork-Free', 'Red-Meat-Free', 'Crustacean-Free', 'Celery-Free', 'Mustard-Free', 'Sesame-Free', 'Lupine-Free', 'Mollusk-Free', 'Alcohol-Free', 'Kosher']
# - Meal Type: ['breakfast']
# - Dish Type: ['desserts']
#
# Recipe: Seedy Oat Crackers
# Parameters used:
# - Cuisine: ['american']
# - Diet Labels: ['High-Fiber', 'Low-Carb', 'Low-Sodium']
# - Health Labels: ['Sugar-Conscious', 'Vegan', 'Vegetarian', 'Pescatarian', 'Dairy-Free', 'Egg-Free', 'Peanut-Free', 'Tree-Nut-Free', 'Soy-Free', 'Fish-Free', 'Shellfish-Free', 'Pork-Free', 'Red-Meat-Free', 'Crustacean-Free', 'Celery-Free', 'Mustard-Free', 'Lupine-Free', 'Mollusk-Free', 'Alcohol-Free', 'Kosher']
# - Meal Type: ['breakfast']
# - Dish Type: ['starter']
#
# Recipe: Better Butter
# Parameters used:
# - Cuisine: ['american']
# - Diet Labels: ['Low-Carb', 'Low-Sodium']
# - Health Labels: ['Sugar-Conscious', 'Low Potassium', 'Kidney-Friendly', 'Keto-Friendly', 'Vegetarian', 'Pescatarian', 'Gluten-Free', 'Wheat-Free', 'Egg-Free', 'Peanut-Free', 'Tree-Nut-Free', 'Soy-Free', 'Fish-Free', 'Shellfish-Free', 'Pork-Free', 'Red-Meat-Free', 'Crustacean-Free', 'Celery-Free', 'Mustard-Free', 'Sesame-Free', 'Lupine-Free', 'Mollusk-Free', 'Alcohol-Free', 'Sulfite-Free', 'FODMAP-Free', 'Kosher', 'Immuno-Supportive']
# - Meal Type: ['lunch/dinner']
# - Dish Type: ['desserts']
#
# Recipe: Honey Nut Cheerios Marshmallow Treats
# Parameters used:
# - Cuisine: ['american']
# - Diet Labels: []
# - Health Labels: ['Kidney-Friendly', 'Egg-Free', 'Peanut-Free', 'Soy-Free', 'Fish-Free', 'Shellfish-Free', 'Pork-Free', 'Red-Meat-Free', 'Crustacean-Free', 'Celery-Free', 'Mustard-Free', 'Sesame-Free', 'Lupine-Free', 'Mollusk-Free', 'Alcohol-Free']
# - Meal Type: ['snack']
# - Dish Type: ['starter']
#
# Recipe: Little coffee caramel cakes
# Parameters used:
# - Cuisine: ['american']
# - Diet Labels: ['Low-Sodium']
# - Health Labels: ['Low Potassium', 'Kidney-Friendly', 'Vegetarian', 'Pescatarian', 'Peanut-Free', 'Tree-Nut-Free', 'Soy-Free', 'Fish-Free', 'Shellfish-Free', 'Pork-Free', 'Red-Meat-Free', 'Crustacean-Free', 'Celery-Free', 'Mustard-Free', 'Sesame-Free', 'Lupine-Free', 'Mollusk-Free', 'Alcohol-Free', 'Kosher']
# - Meal Type: ['lunch/dinner']
# - Dish Type: ['desserts']
#
# Recipe: Fireball Eggnog
# Parameters used:
# - Cuisine: ['american']
# - Diet Labels: ['High-Fiber', 'Low-Fat', 'Low-Sodium']
# - Health Labels: ['Vegetarian', 'Pescatarian', 'Gluten-Free', 'Wheat-Free', 'Peanut-Free', 'Tree-Nut-Free', 'Soy-Free', 'Fish-Free', 'Shellfish-Free', 'Pork-Free', 'Red-Meat-Free', 'Crustacean-Free', 'Celery-Free', 'Mustard-Free', 'Sesame-Free', 'Lupine-Free', 'Mollusk-Free', 'No oil added', 'Kosher']
# - Meal Type: ['lunch/dinner']
# - Dish Type: ['desserts']
#
# Recipe: Candy Cane Peanut Butter Brownies #CandyCaneHacks recipes
# Parameters used:
# - Cuisine: ['french']
# - Diet Labels: ['Low-Sodium']
# - Health Labels: ['Low Potassium', 'Kidney-Friendly', 'Vegetarian', 'Pescatarian', 'Tree-Nut-Free', 'Soy-Free', 'Fish-Free', 'Shellfish-Free', 'Pork-Free', 'Red-Meat-Free', 'Crustacean-Free', 'Celery-Free', 'Mustard-Free', 'Sesame-Free', 'Lupine-Free', 'Mollusk-Free', 'Alcohol-Free', 'Kosher']
# - Meal Type: ['teatime']
# - Dish Type: ['desserts']
#
# Recipe: Pasta Bolognese recipes
# Parameters used:
# - Cuisine: ['mediterranean']
# - Diet Labels: ['High-Fiber']
# - Health Labels: ['Peanut-Free', 'Tree-Nut-Free', 'Soy-Free', 'Fish-Free', 'Shellfish-Free', 'Crustacean-Free', 'Celery-Free', 'Mustard-Free', 'Sesame-Free', 'Lupine-Free', 'Mollusk-Free']
# - Meal Type: ['lunch/dinner']
# - Dish Type: ['main course']
#
# Recipe: WW Broccoli and Parmesan Souffle
# Parameters used:
# - Cuisine: ['french']
# - Diet Labels: []
# - Health Labels: ['Sugar-Conscious', 'Kidney-Friendly', 'Vegetarian', 'Pescatarian', 'Mediterranean', 'Peanut-Free', 'Tree-Nut-Free', 'Soy-Free', 'Fish-Free', 'Shellfish-Free', 'Pork-Free', 'Red-Meat-Free', 'Crustacean-Free', 'Celery-Free', 'Mustard-Free', 'Sesame-Free', 'Lupine-Free', 'Mollusk-Free', 'Alcohol-Free', 'No oil added', 'Sulfite-Free', 'Kosher', 'Immuno-Supportive']
# - Meal Type: ['lunch/dinner']
# - Dish Type: ['starter']
#
# Recipe: Sugar’s Browned-Butter Pecan Balls
# Parameters used:
# - Cuisine: ['american']
# - Diet Labels: ['Low-Sodium']
# - Health Labels: ['Low Potassium', 'Kidney-Friendly', 'Vegetarian', 'Pescatarian', 'Egg-Free', 'Peanut-Free', 'Soy-Free', 'Fish-Free', 'Shellfish-Free', 'Pork-Free', 'Red-Meat-Free', 'Crustacean-Free', 'Celery-Free', 'Mustard-Free', 'Sesame-Free', 'Lupine-Free', 'Mollusk-Free', 'Alcohol-Free', 'Kosher']
# - Meal Type: ['lunch/dinner']
# - Dish Type: ['biscuits and cookies']
#
# Recipe: Chocolate Chip Cookie Dough Cheesecake
# Parameters used:
# - Cuisine: ['american']
# - Diet Labels: []
# - Health Labels: ['Vegetarian', 'Pescatarian', 'Peanut-Free', 'Tree-Nut-Free', 'Fish-Free', 'Shellfish-Free', 'Pork-Free', 'Red-Meat-Free', 'Crustacean-Free', 'Celery-Free', 'Mustard-Free', 'Sesame-Free', 'Lupine-Free', 'Mollusk-Free', 'Alcohol-Free', 'Kosher']
# - Meal Type: ['teatime']
# - Dish Type: ['desserts']
#
# Recipe: No Bake Chocolate Hazelnuts Cookies recipes
# Parameters used:
# - Cuisine: ['american']
# - Diet Labels: ['Low-Sodium']
# - Health Labels: ['Kidney-Friendly', 'Vegetarian', 'Pescatarian', 'Egg-Free', 'Soy-Free', 'Fish-Free', 'Shellfish-Free', 'Pork-Free', 'Red-Meat-Free', 'Crustacean-Free', 'Celery-Free', 'Mustard-Free', 'Sesame-Free', 'Lupine-Free', 'Mollusk-Free', 'Alcohol-Free', 'Kosher']
# - Meal Type: ['teatime']
# - Dish Type: ['biscuits and cookies']
#
# Recipe: Three-Cheese Potato Bake Recipe 4
# Parameters used:
# - Cuisine: ['american']
# - Diet Labels: []
# - Health Labels: ['Gluten-Free', 'Wheat-Free', 'Egg-Free', 'Peanut-Free', 'Tree-Nut-Free', 'Soy-Free', 'Fish-Free', 'Shellfish-Free', 'Pork-Free', 'Red-Meat-Free', 'Crustacean-Free', 'Celery-Free', 'Mustard-Free', 'Sesame-Free', 'Lupine-Free', 'Mollusk-Free', 'Alcohol-Free', 'Sulfite-Free']
# - Meal Type: ['brunch']
# - Dish Type: ['main course']
#
# Recipe: Traditional Fruitcake
# Parameters used:
# - Cuisine: ['american']
# - Diet Labels: ['Low-Sodium']
# - Health Labels: ['Vegetarian', 'Pescatarian', 'Peanut-Free', 'Soy-Free', 'Fish-Free', 'Shellfish-Free', 'Pork-Free', 'Red-Meat-Free', 'Crustacean-Free', 'Celery-Free', 'Mustard-Free', 'Sesame-Free', 'Lupine-Free', 'Mollusk-Free', 'Kosher']
# - Meal Type: ['lunch/dinner']
# - Dish Type: ['desserts']
#
# Recipe: Key Lime Bars
# Parameters used:
# - Cuisine: ['american']
# - Diet Labels: ['Low-Sodium']
# - Health Labels: ['Low Potassium', 'Kidney-Friendly', 'Vegetarian', 'Pescatarian', 'Peanut-Free', 'Tree-Nut-Free', 'Soy-Free', 'Fish-Free', 'Shellfish-Free', 'Pork-Free', 'Red-Meat-Free', 'Crustacean-Free', 'Celery-Free', 'Mustard-Free', 'Sesame-Free', 'Lupine-Free', 'Mollusk-Free', 'Alcohol-Free', 'Kosher']
# - Meal Type: ['lunch/dinner']
# - Dish Type: ['desserts']
#
# Recipe: Perfect potato chips
# Parameters used:
# - Cuisine: ['american']
# - Diet Labels: ['High-Fiber', 'Low-Carb']
# - Health Labels: ['Sugar-Conscious', 'Vegan', 'Vegetarian', 'Pescatarian', 'Dairy-Free', 'Gluten-Free', 'Wheat-Free', 'Egg-Free', 'Tree-Nut-Free', 'Soy-Free', 'Fish-Free', 'Shellfish-Free', 'Pork-Free', 'Red-Meat-Free', 'Crustacean-Free', 'Celery-Free', 'Mustard-Free', 'Sesame-Free', 'Lupine-Free', 'Mollusk-Free', 'Alcohol-Free', 'Sulfite-Free', 'FODMAP-Free', 'Kosher', 'Immuno-Supportive']
# - Meal Type: ['lunch/dinner']
# - Dish Type: ['starter']
#
# Recipe: The Best Chicken Potpie Recipe
# Parameters used:
# - Cuisine: ['american']
# - Diet Labels: ['High-Fiber', 'Low-Carb']
# - Health Labels: ['Peanut-Free', 'Tree-Nut-Free', 'Soy-Free', 'Shellfish-Free', 'Crustacean-Free', 'Mustard-Free', 'Sesame-Free', 'Lupine-Free', 'Mollusk-Free', 'Alcohol-Free', 'Sulfite-Free']
# - Meal Type: ['lunch/dinner']
# - Dish Type: ['desserts']
#
# Recipe: Pecan Tassies recipes
# Parameters used:
# - Cuisine: ['american']
# - Diet Labels: ['High-Fiber']
# - Health Labels: ['Vegetarian', 'Pescatarian', 'Peanut-Free', 'Soy-Free', 'Fish-Free', 'Shellfish-Free', 'Pork-Free', 'Red-Meat-Free', 'Crustacean-Free', 'Celery-Free', 'Mustard-Free', 'Sesame-Free', 'Lupine-Free', 'Mollusk-Free', 'Alcohol-Free', 'Kosher']
# - Meal Type: ['snack']
# - Dish Type: ['biscuits and cookies']
#
# Recipe: Herb-Roasted Chicken
# Parameters used:
# - Cuisine: ['italian']
# - Diet Labels: ['Low-Carb']
# - Health Labels: ['Gluten-Free', 'Wheat-Free', 'Egg-Free', 'Peanut-Free', 'Tree-Nut-Free', 'Soy-Free', 'Fish-Free', 'Shellfish-Free', 'Pork-Free', 'Red-Meat-Free', 'Crustacean-Free', 'Celery-Free', 'Mustard-Free', 'Sesame-Free', 'Lupine-Free', 'Mollusk-Free', 'Alcohol-Free', 'Sulfite-Free']
# - Meal Type: ['lunch/dinner']
# - Dish Type: ['main course']
#
# Recipe: Creamy Cauliflower Hemp Alfredo Sauce recipes
# Parameters used:
# - Cuisine: ['british']
# - Diet Labels: ['High-Fiber']
# - Health Labels: ['Sugar-Conscious', 'Dairy-Free', 'Gluten-Free', 'Wheat-Free', 'Egg-Free', 'Peanut-Free', 'Tree-Nut-Free', 'Fish-Free', 'Shellfish-Free', 'Pork-Free', 'Crustacean-Free', 'Celery-Free', 'Mustard-Free', 'Sesame-Free', 'Lupine-Free', 'Mollusk-Free', 'Alcohol-Free', 'Sulfite-Free', 'Kosher']
# - Meal Type: ['snack']
# - Dish Type: ['condiments and sauces']
#
# Recipe: Chilli Garlic Chunky Chutney recipes
# Parameters used:
# - Cuisine: ['indian']
# - Diet Labels: []
# - Health Labels: ['Sugar-Conscious', 'Kidney-Friendly', 'Vegan', 'Vegetarian', 'Pescatarian', 'Mediterranean', 'Dairy-Free', 'Gluten-Free', 'Wheat-Free', 'Egg-Free', 'Peanut-Free', 'Tree-Nut-Free', 'Soy-Free', 'Fish-Free', 'Shellfish-Free', 'Pork-Free', 'Red-Meat-Free', 'Crustacean-Free', 'Celery-Free', 'Mustard-Free', 'Sesame-Free', 'Lupine-Free', 'Mollusk-Free', 'Alcohol-Free', 'Sulfite-Free', 'Kosher']
# - Meal Type: ['lunch/dinner']
# - Dish Type: ['starter']
#
# Recipe: Creamy Chickpea Curry
# Parameters used:
# - Cuisine: ['indian']
# - Diet Labels: ['High-Fiber']
# - Health Labels: ['Vegetarian', 'Pescatarian', 'Gluten-Free', 'Wheat-Free', 'Egg-Free', 'Tree-Nut-Free', 'Soy-Free', 'Fish-Free', 'Shellfish-Free', 'Pork-Free', 'Red-Meat-Free', 'Crustacean-Free', 'Celery-Free', 'Mustard-Free', 'Sesame-Free', 'Lupine-Free', 'Mollusk-Free', 'Alcohol-Free', 'Sulfite-Free', 'Kosher']
# - Meal Type: ['lunch/dinner']
# - Dish Type: ['main course']
#
# Recipe: Tuscan Kale and Cannellini Stuffed Acorn Squash
# Parameters used:
# - Cuisine: ['italian']
# - Diet Labels: ['Balanced', 'High-Fiber']
# - Health Labels: ['Sugar-Conscious', 'Vegetarian', 'Pescatarian', 'Mediterranean', 'Gluten-Free', 'Wheat-Free', 'Egg-Free', 'Peanut-Free', 'Tree-Nut-Free', 'Soy-Free', 'Fish-Free', 'Shellfish-Free', 'Pork-Free', 'Red-Meat-Free', 'Crustacean-Free', 'Celery-Free', 'Mustard-Free', 'Sesame-Free', 'Lupine-Free', 'Mollusk-Free', 'Alcohol-Free', 'Sulfite-Free', 'Kosher']
# - Meal Type: ['lunch/dinner']
# - Dish Type: ['main course']
#
# Recipe: Stir-fry Sauce Recipe
# Parameters used:
# - Cuisine: ['chinese']
# - Diet Labels: ['Balanced', 'High-Fiber']
# - Health Labels: ['Dairy-Free', 'Egg-Free', 'Peanut-Free', 'Tree-Nut-Free', 'Fish-Free', 'Pork-Free', 'Crustacean-Free', 'Celery-Free', 'Mustard-Free', 'Lupine-Free']
# - Meal Type: ['snack']
# - Dish Type: ['condiments and sauces']
#
# Recipe: Roasted Tofu Lollipops With Pesto recipes
# Parameters used:
# - Cuisine: ['asian']
# - Diet Labels: ['Low-Carb', 'Low-Sodium']
# - Health Labels: ['Sugar-Conscious', 'Low Potassium', 'Kidney-Friendly', 'Keto-Friendly', 'Vegetarian', 'Pescatarian', 'Mediterranean', 'Gluten-Free', 'Wheat-Free', 'Egg-Free', 'Peanut-Free', 'Fish-Free', 'Shellfish-Free', 'Pork-Free', 'Red-Meat-Free', 'Crustacean-Free', 'Celery-Free', 'Mustard-Free', 'Sesame-Free', 'Lupine-Free', 'Mollusk-Free', 'Alcohol-Free', 'FODMAP-Free', 'Kosher']
# - Meal Type: ['lunch/dinner']
# - Dish Type: ['main course']
#
# Recipe: Brussels for Green Beans recipes
# Parameters used:
# - Cuisine: ['american']
# - Diet Labels: ['High-Fiber']
# - Health Labels: ['Paleo', 'Dairy-Free', 'Gluten-Free', 'Wheat-Free', 'Egg-Free', 'Peanut-Free', 'Tree-Nut-Free', 'Soy-Free', 'Fish-Free', 'Shellfish-Free', 'Crustacean-Free', 'Celery-Free', 'Mustard-Free', 'Sesame-Free', 'Lupine-Free', 'Mollusk-Free', 'Alcohol-Free', 'No oil added']
# - Meal Type: ['lunch/dinner']
# - Dish Type: ['main course']
#
# Recipe: Bacon, Pepper and Potato Frittata
# Parameters used:
# - Cuisine: ['italian']
# - Diet Labels: ['Low-Carb']
# - Health Labels: ['Sugar-Conscious', 'Gluten-Free', 'Wheat-Free', 'Peanut-Free', 'Tree-Nut-Free', 'Soy-Free', 'Fish-Free', 'Shellfish-Free', 'Crustacean-Free', 'Celery-Free', 'Mustard-Free', 'Sesame-Free', 'Lupine-Free', 'Mollusk-Free', 'Alcohol-Free', 'No oil added', 'Sulfite-Free', 'Immuno-Supportive']
# - Meal Type: ['breakfast']
# - Dish Type: ['main course', 'egg']
#
# Recipe: Southern Style Cornbread
# Parameters used:
# - Cuisine: ['american']
# - Diet Labels: []
# - Health Labels: ['Sugar-Conscious', 'Low Potassium', 'Kidney-Friendly', 'Vegetarian', 'Pescatarian', 'Peanut-Free', 'Tree-Nut-Free', 'Soy-Free', 'Fish-Free', 'Shellfish-Free', 'Pork-Free', 'Red-Meat-Free', 'Crustacean-Free', 'Celery-Free', 'Mustard-Free', 'Sesame-Free', 'Lupine-Free', 'Mollusk-Free', 'Alcohol-Free', 'Sulfite-Free', 'Kosher']
# - Meal Type: ['teatime']
# - Dish Type: ['bread']
#
# Recipe: Cookie Monster fudge
# Parameters used:
# - Cuisine: ['american']
# - Diet Labels: ['Low-Sodium']
# - Health Labels: ['Vegetarian', 'Pescatarian', 'Peanut-Free', 'Tree-Nut-Free', 'Soy-Free', 'Fish-Free', 'Shellfish-Free', 'Pork-Free', 'Red-Meat-Free', 'Crustacean-Free', 'Celery-Free', 'Mustard-Free', 'Sesame-Free', 'Lupine-Free', 'Mollusk-Free', 'Alcohol-Free', 'Sulfite-Free', 'Kosher']
# - Meal Type: ['teatime']
# - Dish Type: ['desserts']
#
# Recipe: Toe's Best Salsa Recipe
# Parameters used:
# - Cuisine: ['mexican']
# - Diet Labels: ['Low-Fat']
# - Health Labels: ['Vegan', 'Vegetarian', 'Pescatarian', 'Mediterranean', 'DASH', 'Dairy-Free', 'Gluten-Free', 'Wheat-Free', 'Egg-Free', 'Peanut-Free', 'Tree-Nut-Free', 'Soy-Free', 'Fish-Free', 'Shellfish-Free', 'Pork-Free', 'Red-Meat-Free', 'Crustacean-Free', 'Celery-Free', 'Mustard-Free', 'Sesame-Free', 'Lupine-Free', 'Mollusk-Free', 'Alcohol-Free', 'No oil added', 'Sulfite-Free', 'Kosher']
# - Meal Type: ['snack']
# - Dish Type: ['condiments and sauces']
#
# Recipe: Carrot Gelatin Salad
# Parameters used:
# - Cuisine: ['american']
# - Diet Labels: ['Low-Fat', 'Low-Sodium']
# - Health Labels: ['Kidney-Friendly', 'Dairy-Free', 'Gluten-Free', 'Wheat-Free', 'Egg-Free', 'Peanut-Free', 'Tree-Nut-Free', 'Soy-Free', 'Fish-Free', 'Shellfish-Free', 'Pork-Free', 'Red-Meat-Free', 'Crustacean-Free', 'Celery-Free', 'Mustard-Free', 'Sesame-Free', 'Lupine-Free', 'Mollusk-Free', 'Alcohol-Free', 'No oil added']
# - Meal Type: ['lunch/dinner']
# - Dish Type: ['salad']
#
# Recipe: Pressure Cooker Breakfast
# Parameters used:
# - Cuisine: ['american']
# - Diet Labels: ['Low-Carb']
# - Health Labels: ['Sugar-Conscious', 'Peanut-Free', 'Tree-Nut-Free', 'Soy-Free', 'Fish-Free', 'Shellfish-Free', 'Crustacean-Free', 'Celery-Free', 'Mustard-Free', 'Sesame-Free', 'Lupine-Free', 'Mollusk-Free', 'Alcohol-Free', 'Sulfite-Free']
# - Meal Type: ['breakfast']
# - Dish Type: ['main course']
#
# Recipe: Slow Cooker Chicken Taco Soup
# Parameters used:
# - Cuisine: ['mexican']
# - Diet Labels: ['High-Fiber', 'Low-Fat']
# - Health Labels: ['Egg-Free', 'Peanut-Free', 'Tree-Nut-Free', 'Soy-Free', 'Fish-Free', 'Shellfish-Free', 'Pork-Free', 'Red-Meat-Free', 'Crustacean-Free', 'Celery-Free', 'Mustard-Free', 'Sesame-Free', 'Lupine-Free', 'Mollusk-Free']
# - Meal Type: ['lunch/dinner']
# - Dish Type: ['soup']
#
# Recipe: 5-Ingredient Cannolis recipes
# Parameters used:
# - Cuisine: ['italian']
# - Diet Labels: []
# - Health Labels: ['Kidney-Friendly', 'Vegetarian', 'Pescatarian', 'Egg-Free', 'Peanut-Free', 'Tree-Nut-Free', 'Soy-Free', 'Fish-Free', 'Shellfish-Free', 'Pork-Free', 'Red-Meat-Free', 'Crustacean-Free', 'Celery-Free', 'Mustard-Free', 'Sesame-Free', 'Lupine-Free', 'Mollusk-Free', 'Alcohol-Free', 'Kosher']
# - Meal Type: ['lunch/dinner']
# - Dish Type: ['desserts']
#
# Recipe: Peking duck pancakes
# Parameters used:
# - Cuisine: ['american']
# - Diet Labels: ['Low-Carb']
# - Health Labels: ['Sugar-Conscious', 'Kidney-Friendly', 'Peanut-Free', 'Tree-Nut-Free', 'Fish-Free', 'Shellfish-Free', 'Pork-Free', 'Crustacean-Free', 'Celery-Free', 'Mustard-Free', 'Sesame-Free', 'Lupine-Free', 'Mollusk-Free', 'Alcohol-Free', 'Sulfite-Free']
# - Meal Type: ['lunch/dinner']
# - Dish Type: ['pancake']
#
# Recipe: Homemade Granola
# Parameters used:
# - Cuisine: ['american']
# - Diet Labels: ['Low-Sodium']
# - Health Labels: ['Kidney-Friendly', 'Vegan', 'Vegetarian', 'Pescatarian', 'Dairy-Free', 'Egg-Free', 'Peanut-Free', 'Soy-Free', 'Fish-Free', 'Shellfish-Free', 'Pork-Free', 'Red-Meat-Free', 'Crustacean-Free', 'Celery-Free', 'Mustard-Free', 'Sesame-Free', 'Lupine-Free', 'Mollusk-Free', 'Alcohol-Free', 'Kosher']
# - Meal Type: ['breakfast']
# - Dish Type: ['cereals']
#
# Recipe: Easy Chimichurri Sauce
# Parameters used:
# - Cuisine: ['south american']
# - Diet Labels: ['Low-Carb', 'Low-Sodium']
# - Health Labels: ['Sugar-Conscious', 'Low Potassium', 'Kidney-Friendly', 'Keto-Friendly', 'Vegan', 'Vegetarian', 'Pescatarian', 'Paleo', 'Mediterranean', 'DASH', 'Dairy-Free', 'Gluten-Free', 'Wheat-Free', 'Egg-Free', 'Peanut-Free', 'Tree-Nut-Free', 'Soy-Free', 'Fish-Free', 'Shellfish-Free', 'Pork-Free', 'Red-Meat-Free', 'Crustacean-Free', 'Celery-Free', 'Mustard-Free', 'Sesame-Free', 'Lupine-Free', 'Mollusk-Free', 'Alcohol-Free', 'Sulfite-Free', 'Kosher']
# - Meal Type: ['snack']
# - Dish Type: ['condiments and sauces']
#
# Recipe: Falafel
# Parameters used:
# - Cuisine: ['middle eastern']
# - Diet Labels: []
# - Health Labels: ['Sugar-Conscious', 'Kidney-Friendly', 'Vegetarian', 'Pescatarian', 'Mediterranean', 'Egg-Free', 'Peanut-Free', 'Tree-Nut-Free', 'Soy-Free', 'Fish-Free', 'Shellfish-Free', 'Pork-Free', 'Red-Meat-Free', 'Crustacean-Free', 'Celery-Free', 'Mustard-Free', 'Sesame-Free', 'Lupine-Free', 'Mollusk-Free', 'Alcohol-Free', 'Sulfite-Free', 'Kosher']
# - Meal Type: ['lunch/dinner']
# - Dish Type: ['sandwiches']
#
# Recipe: Baked Cavatelli with Sausage and Broccoli Rabe
# Parameters used:
# - Cuisine: ['american']
# - Diet Labels: ['Balanced', 'High-Fiber']
# - Health Labels: ['Egg-Free', 'Peanut-Free', 'Tree-Nut-Free', 'Soy-Free', 'Fish-Free', 'Shellfish-Free', 'Crustacean-Free', 'Celery-Free', 'Mustard-Free', 'Sesame-Free', 'Lupine-Free', 'Mollusk-Free', 'Alcohol-Free']
# - Meal Type: ['lunch/dinner']
# - Dish Type: ['main course']
#
# Recipe: Baked Chimichangas with Nopales and Poblano
# Parameters used:
# - Cuisine: ['american']
# - Diet Labels: ['Balanced']
# - Health Labels: ['Vegetarian', 'Pescatarian', 'Egg-Free', 'Peanut-Free', 'Tree-Nut-Free', 'Fish-Free', 'Shellfish-Free', 'Pork-Free', 'Red-Meat-Free', 'Crustacean-Free', 'Celery-Free', 'Mustard-Free', 'Sesame-Free', 'Lupine-Free', 'Mollusk-Free', 'Alcohol-Free', 'Sulfite-Free', 'Kosher']
# - Meal Type: ['lunch/dinner']
# - Dish Type: ['starter']
#
# Recipe: The Old Hickory Cocktail Recipe
# Parameters used:
# - Cuisine: ['world']
# - Diet Labels: ['Low-Fat', 'Low-Sodium']
# - Health Labels: ['Sugar-Conscious', 'Low Potassium', 'Kidney-Friendly', 'Keto-Friendly', 'Vegan', 'Vegetarian', 'Pescatarian', 'Paleo', 'Dairy-Free', 'Gluten-Free', 'Wheat-Free', 'Egg-Free', 'Peanut-Free', 'Tree-Nut-Free', 'Soy-Free', 'Fish-Free', 'Shellfish-Free', 'Pork-Free', 'Red-Meat-Free', 'Crustacean-Free', 'Celery-Free', 'Mustard-Free', 'Sesame-Free', 'Lupine-Free', 'Mollusk-Free', 'No oil added', 'Kosher', 'Alcohol-Cocktail']
# - Meal Type: ['lunch/dinner']
# - Dish Type: ['alcohol cocktail']
#
# Recipe: Smoked Salmon BLT
# Parameters used:
# - Cuisine: ['nordic']
# - Diet Labels: ['High-Fiber']
# - Health Labels: ['Dairy-Free', 'Peanut-Free', 'Tree-Nut-Free', 'Soy-Free', 'Shellfish-Free', 'Crustacean-Free', 'Celery-Free', 'Sesame-Free', 'Lupine-Free', 'Mollusk-Free', 'Alcohol-Free', 'Sulfite-Free']
# - Meal Type: ['lunch/dinner']
# - Dish Type: ['sandwiches']
#
# Recipe: Glazed Lemon Tea Cookies Recipe
# Parameters used:
# - Cuisine: ['american']
# - Diet Labels: ['Low-Sodium']
# - Health Labels: ['Low Potassium', 'Kidney-Friendly', 'Vegetarian', 'Pescatarian', 'Peanut-Free', 'Tree-Nut-Free', 'Soy-Free', 'Fish-Free', 'Shellfish-Free', 'Pork-Free', 'Red-Meat-Free', 'Crustacean-Free', 'Celery-Free', 'Mustard-Free', 'Sesame-Free', 'Lupine-Free', 'Mollusk-Free', 'Alcohol-Free', 'Kosher']
# - Meal Type: ['teatime']
# - Dish Type: ['biscuits and cookies']
#
# Recipe: Peanut Butter Chocolate Chip Cookie Cups (White Bean Cookies) recipes
# Parameters used:
# - Cuisine: ['american']
# - Diet Labels: ['Balanced', 'High-Fiber']
# - Health Labels: ['Vegetarian', 'Pescatarian', 'Gluten-Free', 'Wheat-Free', 'Egg-Free', 'Tree-Nut-Free', 'Soy-Free', 'Fish-Free', 'Shellfish-Free', 'Pork-Free', 'Red-Meat-Free', 'Crustacean-Free', 'Celery-Free', 'Mustard-Free', 'Sesame-Free', 'Lupine-Free', 'Mollusk-Free', 'Alcohol-Free', 'Kosher']
# - Meal Type: ['teatime']
# - Dish Type: ['biscuits and cookies']
#
# Recipe: Roasted Red Pepper Alfredo Linguine
# Parameters used:
# - Cuisine: ['italian']
# - Diet Labels: ['Balanced']
# - Health Labels: ['Sugar-Conscious', 'Low Potassium', 'Vegan', 'Vegetarian', 'Pescatarian', 'Dairy-Free', 'Egg-Free', 'Peanut-Free', 'Tree-Nut-Free', 'Soy-Free', 'Fish-Free', 'Shellfish-Free', 'Pork-Free', 'Red-Meat-Free', 'Crustacean-Free', 'Celery-Free', 'Mustard-Free', 'Sesame-Free', 'Lupine-Free', 'Mollusk-Free', 'Alcohol-Free', 'Sulfite-Free', 'Kosher']
# - Meal Type: ['lunch/dinner']
# - Dish Type: ['main course']
#
# Recipe: Pumpkin Spice Truffle Bars
# Parameters used:
# - Cuisine: ['american']
# - Diet Labels: ['Low-Sodium']
# - Health Labels: ['Kidney-Friendly', 'Vegetarian', 'Pescatarian', 'Gluten-Free', 'Wheat-Free', 'Egg-Free', 'Peanut-Free', 'Soy-Free', 'Fish-Free', 'Shellfish-Free', 'Pork-Free', 'Red-Meat-Free', 'Crustacean-Free', 'Celery-Free', 'Mustard-Free', 'Sesame-Free', 'Lupine-Free', 'Mollusk-Free', 'Alcohol-Free', 'Sulfite-Free', 'Kosher']
# - Meal Type: ['lunch/dinner']
# - Dish Type: ['desserts']
#
# Recipe: Semolina Halva with Currants
# Parameters used:
# - Cuisine: ['eastern europe']
# - Diet Labels: ['Low-Sodium']
# - Health Labels: ['Kidney-Friendly', 'Vegetarian', 'Pescatarian', 'Egg-Free', 'Peanut-Free', 'Soy-Free', 'Fish-Free', 'Shellfish-Free', 'Pork-Free', 'Red-Meat-Free', 'Crustacean-Free', 'Celery-Free', 'Mustard-Free', 'Sesame-Free', 'Lupine-Free', 'Mollusk-Free', 'Alcohol-Free', 'Kosher']
# - Meal Type: ['breakfast']
# - Dish Type: ['cereals']
#
# Recipe: Almond Joy Muffins
# Parameters used:
# - Cuisine: ['british']
# - Diet Labels: []
# - Health Labels: ['Low Potassium', 'Kidney-Friendly', 'Vegetarian', 'Pescatarian', 'Peanut-Free', 'Tree-Nut-Free', 'Soy-Free', 'Fish-Free', 'Shellfish-Free', 'Pork-Free', 'Red-Meat-Free', 'Crustacean-Free', 'Celery-Free', 'Mustard-Free', 'Sesame-Free', 'Lupine-Free', 'Mollusk-Free', 'Alcohol-Free', 'Kosher']
# - Meal Type: ['teatime']
# - Dish Type: ['desserts']
#
# Recipe: Puff Pastry Pasty
# Parameters used:
# - Cuisine: ['french']
# - Diet Labels: ['Low-Carb']
# - Health Labels: ['Sugar-Conscious', 'Peanut-Free', 'Tree-Nut-Free', 'Fish-Free', 'Shellfish-Free', 'Pork-Free', 'Crustacean-Free', 'Celery-Free', 'Mustard-Free', 'Sesame-Free', 'Lupine-Free', 'Mollusk-Free', 'Alcohol-Free']
# - Meal Type: ['lunch/dinner']
# - Dish Type: ['bread']
#
# Recipe: Yogurt Bowl With Citrus And Rosemary Honey
# Parameters used:
# - Cuisine: ['american']
# - Diet Labels: ['Balanced', 'High-Fiber', 'Low-Sodium']
# - Health Labels: ['Vegetarian', 'Pescatarian', 'Gluten-Free', 'Wheat-Free', 'Egg-Free', 'Peanut-Free', 'Tree-Nut-Free', 'Soy-Free', 'Fish-Free', 'Shellfish-Free', 'Pork-Free', 'Red-Meat-Free', 'Crustacean-Free', 'Celery-Free', 'Mustard-Free', 'Sesame-Free', 'Lupine-Free', 'Mollusk-Free', 'Alcohol-Free', 'Kosher']
# - Meal Type: ['breakfast']
# - Dish Type: ['desserts']
#
# Recipe: Chive Buttered Carrots Recipe 4
# Parameters used:
# - Cuisine: ['american']
# - Diet Labels: ['High-Fiber']
# - Health Labels: ['Vegetarian', 'Pescatarian', 'Gluten-Free', 'Wheat-Free', 'Egg-Free', 'Peanut-Free', 'Tree-Nut-Free', 'Soy-Free', 'Fish-Free', 'Shellfish-Free', 'Pork-Free', 'Red-Meat-Free', 'Crustacean-Free', 'Celery-Free', 'Mustard-Free', 'Sesame-Free', 'Lupine-Free', 'Mollusk-Free', 'Alcohol-Free', 'Sulfite-Free', 'FODMAP-Free', 'Kosher', 'Immuno-Supportive']
# - Meal Type: ['lunch/dinner']
# - Dish Type: ['salad']

# %% [markdown]
# ### Data Storage
#
# We will use PostgreSQL for storing our raw recipe data, however later on we will want to do it in AWS (for production).

# %%
from sqlalchemy import create_engine, Column, Integer, String, JSON, Float
from sqlalchemy.orm import sessionmaker, declarative_base

# %% [markdown]
# Let's test putting in a sample set of recipes into the database.

# %%
recipes[0].keys()
# Out:
# dict_keys(['uri', 'label', 'image', 'images', 'source', 'url', 'shareAs', 'yield', 'dietLabels', 'healthLabels', 'cautions', 'ingredientLines', 'ingredients', 'calories', 'totalCO2Emissions', 'co2EmissionsClass', 'totalWeight', 'totalTime', 'cuisineType', 'mealType', 'dishType', 'totalNutrients', 'totalDaily', 'digest', 'tags', 'collection_timestamp', 'parameter_stats'])

# %%
Base = declarative_base()

class Raw_Recipe(Base):
    __tablename__ = 'raw_recipes'
    
    id = Column(Integer, primary_key=True)
    uri = Column(String, unique=True)
    label = Column(String)
    url = Column(String)
    yield_ = Column(Integer)
    dietLabels = Column(JSON)
    healthLabels = Column(JSON)
    cautions = Column(JSON)
    ingredientLines = Column(JSON)
    ingredients = Column(JSON)
    calories = Column(Float)
    totalWeight = Column(Float)
    totalTime = Column(Integer)
    cuisineType = Column(JSON)
    mealType = Column(JSON)
    dishType = Column(JSON)
    totalNutrients = Column(JSON)
    totalDaily = Column(JSON)
    digest = Column(JSON)
    tags = Column(JSON)

# %%
import os
from dotenv import load_dotenv

load_dotenv()

postgresql_password = os.environ["POSTGRESQL_IIFYMATE_PASSWORD"]

# %%
engine = create_engine(f'postgresql://iifymate:{postgresql_password}@localhost/raw_recipes')
Base.metadata.create_all(engine)
Session = sessionmaker(bind=engine)

# %%
recipes[0]['yield']
# Out:
# 4.0

# %%
def create_raw_recipe(recipe_data):
    return Raw_Recipe(
        uri=recipe_data.get('uri', ''),
        label=recipe_data.get('label', ''),
        url=recipe_data.get('url', ''),
        yield_=recipe_data.get('yield', 0.0),
        dietLabels=recipe_data.get('dietLabels', []),
        healthLabels=recipe_data.get('healthLabels', []),
        cautions=recipe_data.get('cautions', []),
        ingredientLines=recipe_data.get('ingredientLines', []),
        ingredients=recipe_data.get('ingredients', []),
        calories=recipe_data.get('calories', 0.0),
        totalWeight=recipe_data.get('totalWeight', 0.0),
        totalTime=recipe_data.get('totalTime', 0.0),
        cuisineType=recipe_data.get('cuisineType', []),
        mealType=recipe_data.get('mealType', []),
        dishType=recipe_data.get('dishType', []),
        totalNutrients=recipe_data.get('totalNutrients', {}),
        totalDaily=recipe_data.get('totalDaily', {}),
        digest=recipe_data.get('digest', []),
        tags=recipe_data.get('tags', [])
    )

# %%
session = Session()

for i, recipe in enumerate(recipes):
    try:
        session.add(create_raw_recipe(recipe))
    except Exception as e:
        print(f"Failed at index {i}: {e}")
        break

# %%
session.commit()
session.close()
